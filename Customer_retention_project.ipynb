# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
CustomerdataO=pd.read_excel('Customer_retention_Original_data.xlsx') #Original data
CustomerdataC=pd.read_excel('Customer_retention_Coded_data.xlsx') #Coded data

# %%
dfO=pd.DataFrame(CustomerdataO)
dfC=pd.DataFrame(CustomerdataC)

# %%
dfO.shape, dfC.shape
# Out:
# ((269, 71), (269, 71))

# %% [markdown]
# From the above numbers we can observe that there are 71 columns and 269 instances in the dataset

# %%
a=dfO.dtypes

# %%
b=dfC.dtypes

# %%
df1=pd.DataFrame({'Original data dtyes':a,'Coded data dtypes':b})
df1
# Out:
#                                                    Original data dtyes  \
# 10 What is the operating system (OS) of your de...              object
# 11 What browser do you run on your device to ac...              object
# 12 Which channel did you follow to arrive at yo...              object
# 13 After first visit, how do you reach the onli...              object
# 14 How much time do you explore the e- retail s...              object
# ...                                                                ...
# Speedy order delivery                                           object
# Visual appealing web-page layout                                object
# Website is as efficient as before                               object
# Which of the Indian online retailer would you r...              object
# Wild variety of product on offer                                object
#
#                                                    Coded data dtypes
# ...

# %% [markdown]
# From the original dataset we can see that 45 columns are encoded which has categorical data, If we do EDA on encoded data we will not get appropriate analytics, hence we can do EDA on Original data

# %%
#We can now check for what are the columns present in the dataset

pd.set_option('display.max_rows', None)
dfO.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# We can see that there are tabs, extra space in the column names. we can just change the column names by replacing them

# %%
dfO.columns = dfO.columns.str.replace('\t', '')
dfO.columns = dfO.columns.str.rstrip()

# %%
dfO.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you?',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?',
#        '11 What browser do you run on your device to access the website?',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
#        '15 What is your preferred payment Option?',
# ...

# %% [markdown]
# # We can now explore the data in each column and check for their uniqueness, value counts and visualization

# %%
dfO['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
# Visualization of the column

plt.title('Gender count of the customers')
sns.countplot(dfO['1Gender of respondent'])
# Out:
# <AxesSubplot:title={'center':'Gender count of the customers'}, xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# The column '1Gender of respondent' tells us about the gender details of the customer, It has 2 unique value (Male and Female), Number of female customers are 181 and number of male customers are 88

# %%
dfO['2 How old are you?'].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('Age group of the customer')
sns.countplot(dfO['2 How old are you?'])
# Out:
# <AxesSubplot:title={'center':'Age group of the customer'}, xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# From the above data table and graph we can observe that the data in 'How old are you?' column is catogarized into 5 different age which is as following with the number of customers in that respective age group
# * 31-40 years - 81
# * 21-30 years - 79
# * 41-50 yaers - 70
# * Less than 20 years - 20
# * 51 years and above - 19
#
# The plot also tells that maximum number of customers fall under 31-40 years and 21-30 years category

# %%
dfO['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(12,5))
plt.title('City from where customer shops online')
sns.countplot(dfO['3 Which city do you shop online from?'])
# Out:
# <AxesSubplot:title={'center':'City from where customer shops online'}, xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# The column 'Which city do you shop online from?' gives us details about from which city the customer is doing online shoping, there are 11 different cities in the column from where customers shop, below value tells us about which are those cities and how many customers shop from each city
# 1. Delhi - 58
# 2. Greater Noida - 43
# 3. Noida - 40
# 4. Bangalore - 37
# 5. Karnal - 27
# 6. Solan - 18
# 7. Ghaziabad - 18
# 8. Gurgaon - 12
# 9. Merrut - 9
# 10. Moradabad - 5
# 11. Bulandshahr - 2
#
#
# From the above plot we can also observe that highest number of customers are in Delhi, Greater Noida and Noida, Least number of customers are in Bulandshahr

# %%
n = len(pd.unique(dfO['4 What is the Pin Code of where you shop online from?']))
print("No.of.unique values :",n)

dfO['4 What is the Pin Code of where you shop online from?'].unique()
# Out:
# No.of.unique values : 39
# array([110009, 110030, 201308, 132001, 530068, 110011, 110018, 173229,
#        110039, 244001, 122018, 201310, 560037, 203207, 250001, 201005,
#        110044, 201306, 560010, 201305, 110042, 132036, 560018, 110008,
#        560002, 201303, 201312, 203202, 560001, 201304, 560003, 110014,
#        560013, 173212, 122009, 201009, 201008, 201001, 203001],
#       dtype=int64)

# %% [markdown]
# The column '4 What is the Pin Code of where you shop online from?' gives us details about the pincodes of the locations from where the customers are shoping online, it has 39 unique pincodes and value count of each pincode is as below

# %%
dfO['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173229     9
# 173212     9
# 560010     8
# 132036     8
# 122018     8
# 560037     8
# 110008     7
# 110011     7
# 201306     7
# 110014     6
# 110018     6
# 201305     5
# 201008     5
# 201009     5
# 201312     5
# 244001     5
# 530068     5
# 122009     4
# 201001     4
# 560003     4
# 201304     4
# 110009     4
# 201303     4
# 560002     4
# 560018     4
# 110042     4
# 110030     4
# 201005     4
# 110039     4
# 560013     3
# 203001     2
# 203202     1
# 560001     1
# 203207     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
dfO['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('Customers shopping online since')
sns.countplot(dfO['5 Since How Long You are Shopping Online ?'])
# Out:
# <AxesSubplot:title={'center':'Customers shopping online since'}, xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# The column '5 Since How Long You are Shopping Online ?' gives us the details about since how long the customer is doing online shoping, the data in this column has 5 categories which is shows as below along with number of customers in each respective category.
# 1. Above 4 years - 98
# 2. 2-3 years - 65
# 3. 3-4 years - 47
# 4. Less than 1 year - 43
# 5. 1-2 years - 16
#
# We can also observe that the maximum number of customers fall in the category 'Above 4 years', which tells that most of customers are doing online shopping for more than 4 years

# %%
dfO['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(14,5))
plt.title('Number of time customer nade online shopping')
sns.countplot(dfO['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:title={'center':'Number of time customer nade online shopping'}, xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# In the column '6 How many times you have made an online purchase in the past 1 year?' we can observe that the data gives us details about how many time each customer did online shopping, that data in this column is catogorized into 6 categories which are as following along with the number of customers falling under each catergory
# 1. Less than 10 times - 114
# 2. 31-40 times - 63
# 3. 41 times and above - 47
# 4. 11-20 times - 29
# 5. 21-30 times - 10
# 6. 42 times and above - 6
#
# Also we can observe that maximum number of customers (114 members) did online shopping less than 10 times and minimum number of customers (6 members) did 42 times or above times.

# %%
dfO['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# In the column '7 How do you access the internet while shopping on-line?' we can see that there are only 3 categories but it is distributed as 4 categories as 'Mobile internet' and 'Mobile Internet' category is same we can make them as one

# %%
dfO['7 How do you access the internet while shopping on-line?'] = dfO['7 How do you access the internet while shopping on-line?'].replace({'Mobile Internet':'Mobile internet'})

# %%
dfO['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('Customers internet access')
sns.countplot(dfO['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:title={'center':'Customers internet access'}, xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# Now from the '7 How do you access the internet while shopping on-line?' column we can see the details of how the customers accessed internet while doing the online shopping, again the data here is categories into 3 different categories, the below table gives us the details about which are the categories and how many customers fall under each category
# 1. Mobile internet - 189
# 2. Wi-Fi - 76
# 3. Dial-up - 4
#
# Maximum number of customers (189 members) accessed internet through Mobile internet while doing online shopping and minimum number of customer accessed through Dial-up and shopped online

# %%
dfO['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(8,5))
plt.title('Kind of device through which online shopping was done')
sns.countplot(dfO['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:title={'center':'Kind of device through which online shopping was done'}, xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# The column '8 Which device do you use to access the online shopping?' tell us details about through which kind of device the customer made online shopping, the data in this column is categorised into 4 different categories as follow which gives the number of customers falling in each category
# 1. Smartphone - 141
# 2. Laptop - 86
# 3. Desktop - 30
# 4. Tablet - 12
#
# From the above count plot we can observe that maximum number of customers (141) shopped through Smartphones and minimum number of customers (12) shopped through Tablet.

# %%
dfO['9 What is the screen size of your mobile device?'].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(8,5))
plt.title('Screen size of the devices through which shopping was done')
sns.countplot(dfO['9 What is the screen size of your mobile device?'])
# Out:
# <AxesSubplot:title={'center':'Screen size of the devices through which shopping was done'}, xlabel='9 What is the screen size of your mobile device?', ylabel='count'>

# %% [markdown]
# The column '9 What is the screen size of your mobile device?' gives us the details about the size of the screens of devices through which customers did online shopping, the data in this is categorised into 4 different categiries as 4.7, 5.5, 5 inches and other sizes falls under 'Others' category. The table below tells about the number of customers in each category
# 1. Others - 134
# 2. 5.5 inches - 99
# 3. 4.7 inches - 29
# 4. 5 inches - 7
#
# From the above count plot we can observe that Most of the customers fall under 'Other' category and least number of customers shopped from the device whose screen size is 5 inches

# %%
dfO['10 What is the operating system (OS) of your device?'].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('OS of the device through which customers shopped')
sns.countplot(dfO['10 What is the operating system (OS) of your device?'])
# Out:
# <AxesSubplot:title={'center':'OS of the device through which customers shopped'}, xlabel='10 What is the operating system (OS) of your device?', ylabel='count'>

# %% [markdown]
# The column '10 What is the operating system (OS) of your device?' tell us the details about OS of the devices through which customers did online shopping, the data in this is categorized into 3 different categories which are as mentioned below along with the count of customers in each category
# 1. Window/windows Mobile - 122
# 2. Android - 85
# 3. IOS/Mac - 62
#
# FRom the above count plot we can observe that maximum number of customers (122) shopped from Window/windows Mobile and least (62) shopped from IOS/Mac.

# %%
dfO['11 What browser do you run on your device to access the website?'].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('Browser ran on device to access shopping website')
sns.countplot(dfO['11 What browser do you run on your device to access the website?'])
# Out:
# <AxesSubplot:title={'center':'Browser ran on device to access shopping website'}, xlabel='11 What browser do you run on your device to access the website?', ylabel='count'>

# %% [markdown]
# The column '11 What browser do you run on your device to access the website?' tell us details about which browser customers used in their device to access the shopping website, the data in this is categorized into 4 categories and it is as following along with the count of customers falling in each category
# 1. Google chrome - 216
# 2. Safari - 40
# 3. Opera - 8
# 4. Mozilla Firefox - 5
#
# From the above table and countplot we can observe that maximum number of customers (216) accessed the website through Google chrome and minimum number of customers (5) accessed from Mozilla Firefox

# %%
dfO['12 Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('What inspired the customers to shop online')
sns.countplot(dfO['12 Which channel did you follow to arrive at your favorite online store for the first time?'])
# Out:
# <AxesSubplot:title={'center':'What inspired the customers to shop online'}, xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?', ylabel='count'>

# %% [markdown]
# The column '12 Which channel did you follow to arrive at your favorite online store for the first time?' tells us details about what inspired the customer to do online shopping for the first time, the data data here is categorized into 3 categories which and gives the count of customers in each category as following
# 1. Search Engine - 230
# 2. Content Marketing - 20
# 3. Display Adverts - 19
#
# From the above count plot we can observe that maximum number od customers (230) shopped online for the first time through 'search Engine' and least (19) shopped online for the first time getting inspired by 'Display Advertises'

# %%
dfO['13 After first visit, how do you reach the online retail store?'].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('Medium by which customer continue shopping after first visit')
sns.countplot(dfO['13 After first visit, how do you reach the online retail store?'])
# Out:
# <AxesSubplot:title={'center':'Medium by which customer continue shopping after first visit'}, xlabel='13 After first visit, how do you reach the online retail store?', ylabel='count'>

# %% [markdown]
# The column '13 After first visit, how do you reach the online retail store?' tells us details about how the customers continued shopping after visiting the website first, this data is categorized into 5 different categories as shown below also tells us about how many customers fall in each category
# 1. Search Engine - 87
# 2. Via application - 86
# 3. Direct URL - 70
# 4. E-mail - 18
# 5. Social Media - 8
#
# From the above count plot we can observe that maximum number of customers continued their shopping through Search engine (87) and Application (86) and least number of customers shopped through Social media(8)

# %%
dfO['14 How much time do you explore the e- retail store before making a purchase decision?'].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(14,5))
plt.title('Time customer takes to explore e-retail store before shopping')
sns.countplot(dfO['14 How much time do you explore the e- retail store before making a purchase decision?'])
# Out:
# <AxesSubplot:title={'center':'Time customer takes to explore e-retail store before shopping'}, xlabel='14 How much time do you explore the e- retail store before making a purchase decision?', ylabel='count'>

# %% [markdown]
# The column '14 How much time do you explore the e- retail store before making a purchase decision?' tells us details about how much time each customer spends on e-retail store before making a decission of shopping any online product, the data in this column is categorized into 5 different categories along with number of customers falling under each category
# more than 15 mins - 123
# 1. 6-10 mins - 71
# 2. 11-15 mins - 46
# 3. Less than 1 min - 15
# 4. 1-5 mins - 14
#
# From the above count plot we can observe that maximum number customers (123) spend more than 15 minutes on the e-retail store before making a choise of shopping online and minimum number of customers fall in the category of spending 1-5 min (14) or less than 1 min (15)

# %%
dfO['15 What is your preferred payment Option?'].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('Preferred payment method')
sns.countplot(dfO['15 What is your preferred payment Option?'])
# Out:
# <AxesSubplot:title={'center':'Preferred payment method'}, xlabel='15 What is your preferred payment Option?', ylabel='count'>

# %% [markdown]
# The column '15 What is your preferred payment Option?' tells us details about what method customers use for doing payment, the data in this is categorized into 3 different categories alone with number of customers falling under each category as below
# 1. Credit/Debit cards - 148
# 2. Cash on delivery (CoD) - 76
# 3. E-wallets (Paytm, Freecharge etc.) - 45
#
# From the above countplot we can observe that maximum number of customers (148) do their payments through Credit/Debit cards and where as minimum number of customers (45) do payments using E-wallets (Paytm, Freecharge etc.) and COD is done by 76 customers

# %%
dfO['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(10,5))
plt.title('How frequently customer leaves the cart after selecting items without shopping')
sns.countplot(dfO['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'])
# Out:
# <AxesSubplot:title={'center':'How frequently customer leaves the cart after selecting items without shopping'}, xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?', ylabel='count'>

# %% [markdown]
# The column '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?' tells us details about how frequently costomer leaves the cart without shopping after adding items in, the data in this is categorised in 4 categories, below is the data which tells us about how many customers fall under each category
# 1. Sometimes - 171
# 2. Never - 48
# 3. Frequently - 35
# 4. Very frequently - 15
#
# From the above countplot we can observe that the maximum number of customers (171) leave the cart unshopped sometimes and least number of customers (35) leave the cart unshopped after adding intems to cart very frequently

# %%
dfO['17 Why did you abandon the “Bag”, “Shopping Cart”?'].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(14,5))
plt.title('Reason for leaving cart unshopped')
sns.countplot(dfO['17 Why did you abandon the “Bag”, “Shopping Cart”?'])
# Out:
# <AxesSubplot:title={'center':'Reason for leaving cart unshopped'}, xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?', ylabel='count'>

# %% [markdown]
# The column '17 Why did you abandon the “Bag”, “Shopping Cart”?' tells us details about the reasons why customer is leaving the cart witout shopping after adding items to cart
# 1. Better alternative offer - 133
# 2. Promo code not applicable - 54
# 3. Change in price - 37
# 4. Lack of trust - 31
# 5. No preferred mode of payment - 14
#
# From the above countplot we can observe that 133 customers give reason that they got better alternative offer on the intem for their abondness, 14 customers give reason that they had no preferred mode of payment for them to abondon

# %%
dfO['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
# Visualization of the column
plt.figure(figsize=(14,5))
plt.title('Feedback on content of product on website whether it should be easy or not')
sns.countplot(dfO['18 The content on the website must be easy to read and understand'])
# Out:
# <AxesSubplot:title={'center':'Feedback on content of product on website whether it should be easy or not'}, xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# The column '18 The content on the website must be easy to read and understand' tells us about customers opinion about content on website which tells them about the product. this data is categorised into 4 categories as show below
# 1. Strongly agree (5) - 164
# 2. Agree (4) - 80
# 3. Strongly disagree (1) - 18
# 4. Indifferent (3) - 7
#
# From the above count plot we can observe that 164 customers strongly agree that the product details on the website should be easy to read and understand

# %% [markdown]
# In the similar way the columns from 19 to 47 gives us details about customers feedbacks on different parameters, we can see the feedback response of each parameter by plotting countplot all together instead of studying them one by one

# %%
Feedback_cols=dfO.iloc[:,18:47]
dff=pd.DataFrame(Feedback_cols)

# %%
dff.shape
# Out:
# (269, 29)

# %%
# Visualization of the column
for col in dff:
    plt.figure(figsize=(10,5))
    sns.countplot(dff[col])

# %% [markdown]
# Above countplots gives us the details about customers feedbacks on various parameters in e-retail store (Customer satisfaction)

# %% [markdown]
# We can describe the plots as follows
# * Column 19 : This column tells us about how satisfied customers are with the information on similar product which would be helpful for comparision, Most of the customers strongly agree with importance of information on similar products
# * Column 20 : This column tells us about how strogly customers agree that the information on listed seller and product being offered is important for purchase decision, here most of the costomers strongly agree that complete information of product is important to make decision for purchase
# * Column 21 : This column tells us about how important it is to give relevent information on listed products must be stated clearly, in this most of the customers agree for the aspect
# * Column 22 : This column tells us about how friendly the webseite is for the customers to navigate, Maximum number of customers strogly agree that the websites are easy to navigate
# * Column 23 : This column tells us about how satisfied the customers are with loading and processing speed, Maximum customers Strongly agree and agree with that loading and processing speed is good in the websites
# * Column 24 : This column tells us about how satisfied the customers are with user friendly interface of the website, Maximum number of customers strongly agree with this aspet
# * Column 25 : This column tells us about the convenience of payment methods, Maximum number of customers strongly agree that the payment methods are convenient enough
# * Column 26 : This column tells us about whether the transactions are made at the stipulated time or not, Maximum number of customers strongly agree that the transactions ate made at the stipulated time
# * Column 27 : This column tells us about how empathitically the customers were treated and assisted with their queries, maximum number of customers strongly agree that they were treated empathically and assisted with their queries
# * Column 28 : This column tells us about how satisfied the customers are with the privacy of their data, maximum number of customers strongly agree that their information was kept confidential
# * Column 29 : This column tells us about how satisfied the customers are with responsiveness, availability of several communication channels(email, online rep, teitter, phone etc.), maximum number of customers strongly agree that communication channels are responsive and available
# * Column 30 : This column tells us about how satisfied customers are with monetary benefits and discounts on online shopping, maximum number of customers strongly agree that they get good monetory benifits discounts on online shopping
# * Column 31 : This column tells us about how enjoyable the online shopping is for customers, maximum number of customers strongly agree that they the enjoyment is derived from online shopping
# * Column 32 : This column tells us about how convenient and flexible online shopping is, maximum number of customers strongly agree that shopping online is convenient and flexible
# * Column 33 : This column tells us about how important return and replacement policy is to make a purchase decision, maximum number of customers strongly agree that return and replacement policy is important to make purchase decision
# * Column 34 : This column tells us about how important it is to gain access to loyalty programs that benifit online shopping, maximum number of customers strongly agree with this aspect
# * Column 35 : This column tells us about how important it is to diplay quality information on the website to improve satisfaction of customers, maximum number of customers strongly agree that it is important to display quality information on website improves satisfaction of customers
# * Column 36 : This column tells us about how important it is to have a good quality website or application to satisfy users while shopping online, maximum number of customers strongly agree that it is important to have a good quality website and application to satisfy users while shopping online
# * Column 37 : This column tells us about how important it is to create net benifit from shopping online which leads to user satisfaction, maximum number of customers strongly agree that net benifit derived from online shopping leads to user satisfaction
# * Column 38 : This column tells us about how important trust is to create user satisfaction, maximum number of customers strongly agree that trust is important to create user satisfaction in customers
# * Column 39 : This column tells us about how important it is to provide a wide variety of products in different categories, maximum customers strongly agree that it is important to provide wide variety of listed products in all categories to attract customers
# * Column 40 : This column tells us about how important it is to provide provision of complete and relevant product information, maximum number of customers strongly agree that provision of complete and relevant product information is important
# * Column 41 : This column tells us about Monetory savings done by online shopping, maximum number of customers strongly agree that monetory saving is done by shopping online
# * Column 42 : This column tells us about the convenience in paternizing the online retailer, maximum number of customers strongly agree with the paternizing the online retailer is important for user satisfaction
# * Column 43 : This column tells us about how adventurous it is to shop online, maximum number of customers agree that it is adventurous to shop online
# * Column 44 : This column tells us about if customers social status is enhanced by shopping on preferred e-retail store, maximum number of customers tell that it is indefferent to this aspect
# * Column 45 : This column tells us about whether customer feels gratified by shopping on their preferred e-retail store, maximum customers tell it is indefferent to this aspect
# * Column 46 : This column tells us about whether certain roles are improved in customers by shopping online, maximum number of customers tell that they agree and indefferent with this aspect
# * Column 47 : This column tells us about whether customers money spent on shopping is valued or not, maximum number of customers strongly agre that their money spent on shopping is valued

# %% [markdown]
# # Understanding further 24 columns and what details they explain

# %%
df11=dfO.iloc[:,47:]
df11.columns
# Out:
# Index(['From the following, tick any (or all) of the online retailers you have shopped from;',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options', 'Speedy order delivery',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
#        'Late declaration of price (promotion, sales period)',
# ...

# %%
from collections import Counter

# %%
L48=[i.split(',',-1)for i in df11['From the following, tick any (or all) of the online retailers you have shopped from;']]
FL48=[item for sublist in L48 for item in sublist]
print(len(FL48))
print(Counter(FL48))
plt.figure(figsize=(10,5))
plt.title('Different online retailers through which customers shop')
plt.hist(FL48);
plt.show()
# Out:
# 968
# Counter({'Amazon.in': 269, ' Flipkart.com': 221, ' Snapdeal.com': 182, ' Paytm.com': 150, ' Myntra.com': 146})

# %% [markdown]
# The column 'From the following, tick any (or all) of the online retailers you have shopped from;' tell us details about which online retails customers use for shopping online, and from the above plot we can observe that most pf the customers shop from Amazon and Flipkart

# %%
L49=[i.split(',',-1)for i in df11['Easy to use website or application']]
FL49=[item for sublist in L49 for item in sublist]
print(len(FL49))
print(Counter(FL49))
FL49=[x.strip(' ') for x in FL49]
plt.figure(figsize=(10,5))
plt.title('Wesites or applications which are easy to use')
plt.hist(FL49);
plt.show()
# Out:
# 852
# Counter({'Amazon.in': 249, ' Flipkart.com': 193, ' Myntra.com': 147, ' Snapdeal.com': 130, ' Paytm.com': 113, 'Paytm.com': 12, 'Flipkart.com': 8})

# %% [markdown]
# The column 'Easy to use website or application' tells us about customers' opinion on which application or website is easy to use, Customers gave maximum vote for amazon and flipkart

# %%
L50=[i.split(',',-1)for i in df11['Visual appealing web-page layout']]
FL50=[item for sublist in L50 for item in sublist]
print(len(FL50))
print(Counter(FL50))
FL50=[x.strip(' ') for x in FL50]
plt.figure(figsize=(10,5))
plt.title('Visual appealing of webpage layout')
plt.hist(FL50);
plt.show()
# Out:
# 645
# Counter({'Amazon.in': 227, ' Flipkart.com': 148, ' Myntra.com': 100, ' Paytm.com': 67, ' Snapdeal.com': 61, 'Flipkart.com': 27, 'Myntra.com': 15})

# %% [markdown]
# The column 'Visual appealing web-page layout' gives us details about which online shopping site gives us a better visual appearance, from the above plot we can analize that maximum votes is given for Amazon and least votes are given for Snapdeal.com

# %%
L51=[i.split(',',-1)for i in df11['Wild variety of product on offer']]
FL51=[item for sublist in L51 for item in sublist]
print(len(FL51))
FL51=[x.strip(' ') for x in FL51]
print(Counter(FL51))
plt.figure(figsize=(10,5))
plt.title('Wide variety of offers given')
plt.hist(FL51);
plt.show()
# Out:
# 502
# Counter({'Amazon.in': 220, 'Flipkart.com': 184, 'Myntra.com': 64, 'Paytm.com': 20, 'Snapdeal.com': 14})

# %% [markdown]
# The column 'Wild variety of product on offer' tells us details about which e-retail site gives wide variety of offeres on the products, Customers have shared their opinion that Amazon gives the hiest offers on the products and least voting is given for snapdeal

# %%
L52=[i.split(',',-1)for i in df11['Complete, relevant description information of products']]
FL52=[item for sublist in L52 for item in sublist]
print(len(FL52))
FL52=[x.strip(' ') for x in FL52]
print(Counter(FL52))
plt.figure(figsize=(10,5))
plt.title('e-retail store that given complete, relevant description information of products')
plt.hist(FL52);
plt.show()
# Out:
# 614
# Counter({'Amazon.in': 238, 'Flipkart.com': 194, 'Myntra.com': 64, 'Snapdeal.com': 59, 'Paytm.com': 59})

# %% [markdown]
# The column 'Complete, relevant description information of products' gives us details about which e-retail store gives the complete, relevant description information of products, Maximum number of customers (238) have voted to Amazon.com that they give relevant and complete description information of products and least votes (59) are given for Paytm and snapdeal

# %%
L53=[i.split(',',-1)for i in df11['Fast loading website speed of website and application']]
FL53=[item for sublist in L53 for item in sublist]
print(len(FL53))
FL53=[x.strip(' ') for x in FL53]
print(Counter(FL53))
plt.figure(figsize=(10,5))
plt.title('website or application that loads fast')
plt.hist(FL53);
plt.show()
# Out:
# 665
# Counter({'Amazon.in': 249, 'Flipkart.com': 162, 'Paytm.com': 99, 'Snapdeal.com': 81, 'Myntra.com': 74})

# %% [markdown]
# The column 'Fast loading website speed of website and application' tells us about which e-retail store's website or application loads or works fast, Customers have given maximum voting for Amazon.com (249) and minimum votes are given for Myntra (74)

# %%
L54=[i.split(',',-1)for i in df11['Reliability of the website or application']]
FL54=[item for sublist in L54 for item in sublist]
print(len(FL54))
FL54=[x.strip(' ') for x in FL54]
print(Counter(FL54))
plt.figure(figsize=(10,5))
plt.title('Reliability of the website or application')
plt.hist(FL54);
plt.show()
# Out:
# 578
# Counter({'Amazon.in': 227, 'Flipkart.com': 146, 'Paytm.com': 96, 'Myntra.com': 64, 'Snapdeal.com': 45})

# %% [markdown]
# The column 'Reliability of the website or application' tells us about which application or website has high reliability, customers have voted that Amazon.com's application or website is highly reliable and least votes are given for Snapdeal.com (45)

# %%
L55=[i.split(',',-1)for i in df11['Quickness to complete purchase']]
FL55=[item for sublist in L55 for item in sublist]
print(len(FL55))
FL55=[x.strip(' ') for x in FL55]
print(Counter(FL55))
plt.figure(figsize=(10,5))
plt.title('Quickness to complete purchase')
plt.hist(FL55);
plt.show()
# Out:
# 588
# Counter({'Amazon.com': 215, 'Flipkart.com': 158, 'Paytm.com': 107, 'Myntra.com': 79, 'Snapdeal': 29})

# %% [markdown]
# The column 'Quickness to complete purchase' tells us about customers voting on Quickness to complete purchase, Maximum number of customers voted that Amazon.com (215) is quick to complete the purchase and minimum voting is given for Snapdeal (29)

# %%
L56=[i.split(',',-1)for i in df11['Availability of several payment options']]
FL56=[item for sublist in L56 for item in sublist]
print(len(FL56))
FL56=[x.strip(' ') for x in FL56]
print(Counter(FL56))
plt.figure(figsize=(10,5))
plt.title('Availability of several payment options')
plt.hist(FL56);
plt.show()
# Out:
# 722
# Counter({'Amazon.in': 215, 'Flipkart.com': 203, 'Myntra.com': 132, 'Snapdeal.com': 90, 'Patym.com': 82})

# %% [markdown]
# The column 'Availability of several payment options' tells us customers opinion on availability of several payment options in e-retail stores, Maximum voting is given for Amazon.com (215) and Flipkart.com (203), Minimum voting is given for Paytm.com (82)

# %%
L57=[i.split(',',-1)for i in df11['Speedy order delivery']]
FL57=[item for sublist in L57 for item in sublist]
print(len(FL57))
FL57=[x.strip(' ') for x in FL57]
print(Counter(FL57))
plt.figure(figsize=(10,5))
plt.title('Speedy order delivery')
plt.hist(FL57);
plt.show()
# Out:
# 481
# Counter({'Amazon.in': 240, 'Flipkart.com': 162, 'Snapdeal.com': 50, 'Myntra.com': 29})

# %% [markdown]
# The column 'Speedy order delivery' tells us about customers opinion on which e-retail store gives speedy deliver of products, from the above plot we can observe that customers have given maximum voting for Amazon.com (240) that speedy delivery is given and minimum votes are given for Myntra (29)

# %%
L57=[i.split(',',-1)for i in df11['Privacy of customers’ information']]
FL57=[item for sublist in L57 for item in sublist]
print(len(FL57))
FL57=[x.strip(' ') for x in FL57]
print(Counter(FL57))
plt.figure(figsize=(10,5))
plt.title('Privacy of customers’ information')
plt.hist(FL57);
plt.show()
# Out:
# 562
# Counter({'Amazon.in': 221, 'Flipkart.com': 150, 'Myntra.com': 78, 'Paytm.com': 68, 'Snapdeal.com': 45})

# %% [markdown]
# The column 'Privacy of customers’ information' tells us about customers' opinion on which e-retail store gives strong privacy on customers' information, Maximum customers voted that Amazon.in (221) maintains strong privacy on customers' information, least votes are given for snapdeal.com (45)

# %%
L58=[i.split(',',-1)for i in df11['Security of customer financial information']]
FL58=[item for sublist in L58 for item in sublist]
print(len(FL58))
FL58=[x.strip(' ') for x in FL58]
print(Counter(FL58))
plt.figure(figsize=(10,5))
plt.title('Security of customer financial information')
plt.hist(FL58);
plt.show()
# Out:
# 634
# Counter({'Amazon.in': 206, 'Flipkart.com': 149, 'Snapdeal.com': 100, 'Myntra.com': 91, 'Paytm.com': 88})

# %% [markdown]
# The column 'Security of customer financial information' tells us about customers opinion on which application or website gives strong security of customer financial information, from the about plot we can observe that customers voted maximum for Amazon.in (206) that they provide strong security on customers financial information and least voting are given for paytm.com (88)

# %%
L59=[i.split(',',-1)for i in df11['Perceived Trustworthiness']]
FL59=[item for sublist in L59 for item in sublist]
print(len(FL59))
FL59=[x.strip(' ') for x in FL59]
print(Counter(FL59))
plt.figure(figsize=(10,5))
plt.title('Perceived Trustworthiness')
plt.hist(FL59);
plt.show()
# Out:
# 556
# Counter({'Amazon.in': 227, 'Flipkart.com': 143, 'Myntra.com': 88, 'Snapdeal.com': 74, 'Paytm.com': 24})

# %% [markdown]
# The column 'Perceived Trustworthiness' tells us about customers opinion on which e-retail app or website is trustworthy, customers have voted that Amazon.in (227) is trustworthy and least votes are given for paytm.com (24)

# %%
L60=[i.split(',',-1)for i in df11['Presence of online assistance through multi-channel']]
FL60=[item for sublist in L60 for item in sublist]
print(len(FL60))
FL60=[x.strip(' ') for x in FL60]
print(Counter(FL60))
plt.figure(figsize=(10,5))
plt.title('Presence of online assistance through multi-channel')
plt.hist(FL60);
plt.show()
# Out:
# 588
# Counter({'Amazon.in': 229, 'Flipkart.com': 136, 'Myntra.com': 111, 'Snapdeal': 87, 'Paytm.com': 25})

# %% [markdown]
# The column 'Presence of online assistance through multi-channel' tells us about which app or website has the better presence of online assistance through multi-channel, customers voted that better presence of online assistance through multi-channel is given by Amazon.in (229) and least votings are given for Paytem.com (25)

# %% [markdown]
# # The upcoming columns is to discuss about the negative characteristics of the e-retail store's website or Application

# %%
L61=[i.split(',',-1)for i in df11['Longer time to get logged in (promotion, sales period)']]
FL61=[item for sublist in L61 for item in sublist]
print(len(FL61))
FL61=[x.strip(' ') for x in FL61]
print(Counter(FL61))
plt.figure(figsize=(10,5))
plt.title('Longer time to get logged in (promotion, sales period)')
plt.hist(FL61);
plt.show()
# Out:
# 417
# Counter({'Amazon.in': 135, 'Flipkart.com': 103, 'Paytm.com': 77, 'Snapdeal.com': 67, 'Myntra.com': 35})

# %% [markdown]
# The column 'Longer time to get logged in (promotion, sales period)' tells us about customers opinion on which e-retails' app or website takes longer time to get logged in, Customers have voted that Amazon.in (135) takes longer time to login due to promotions, sales period etc. least votes are given for Myntra.com (35)

# %%
L62=[i.split(',',-1)for i in df11['Longer time in displaying graphics and photos (promotion, sales period)']]
FL62=[item for sublist in L62 for item in sublist]
print(len(FL62))
FL62=[x.strip(' ') for x in FL62]
print(Counter(FL62))
plt.figure(figsize=(10,5))
plt.title('Longer time in displaying graphics and photos (promotion, sales period)')
plt.hist(FL62);
plt.show()
# Out:
# 414
# Counter({'Amazon.in': 126, 'Flipkart.com': 94, 'Snapdeal.com': 92, 'Myntra.com': 74, 'Paytm.com': 28})

# %% [markdown]
# The column 'Longer time in displaying graphics and photos (promotion, sales period)' tells us about opinion of customers on which app or website takes longer time to display the graphics and photos, From the above plot we can observe that maximum number of customers have voted that Amazon.in (126) takes longer time to display the graphics and photos, next stands Flipkart.com (94) and Snapdeal.com (92), the least votes are given for Paytm.com(28)

# %%
L63=[i.split(',',-1)for i in df11['Late declaration of price (promotion, sales period)']]
FL63=[item for sublist in L63 for item in sublist]
print(len(FL63))
FL63=[x.strip(' ') for x in FL63]
print(Counter(FL63))
plt.figure(figsize=(10,5))
plt.title('Late declaration of price (promotion, sales period)')
plt.hist(FL63);
plt.show()
# Out:
# 294
# Counter({'Myntra.com': 75, 'Paytm.com': 72, 'Amazon.in': 56, 'snapdeal.com': 48, 'Flipkart.com': 43})

# %% [markdown]
# The column 'Late declaration of price (promotion, sales period)' tells us about customers opinion on which r-retail's app or website declares the price lately, customers have voted that Myntra.com (75) delays in declaring the price, least votes are given for Flipkart.com (43).

# %%
L64=[i.split(',',-1)for i in df11['Longer page loading time (promotion, sales period)']]
FL64=[item for sublist in L64 for item in sublist]
print(len(FL64))
FL64=[x.strip(' ') for x in FL64]
print(Counter(FL64))
plt.figure(figsize=(10,5))
plt.title('Longer page loading time (promotion, sales period)')
plt.hist(FL64);
plt.show()
# Out:
# 354
# Counter({'Paytm.com': 94, 'Myntra.com': 68, 'Amazon.in': 68, 'Snapdeal.com': 63, 'Flipkart.com': 61})

# %% [markdown]
# The column 'Longer page loading time (promotion, sales period)' tells us about customers opinion on which app or website takes longer time for loading the page, from the above plot we can observe that maximum cotomers have voted for Paytm.com (94) that it takes longer time to load the page, the votes are almost evenly distributed for Myntra, Smazon, Snapdeal and Flipkart

# %%
L65=[i.split(',',-1)for i in df11['Limited mode of payment on most products (promotion, sales period)']]
FL65=[item for sublist in L65 for item in sublist]
print(len(FL65))
FL65=[x.strip(' ') for x in FL65]
print(Counter(FL65))
plt.figure(figsize=(10,5))
plt.title('Limited mode of payment on most products (promotion, sales period)')
plt.hist(FL65);
plt.show()
# Out:
# 333
# Counter({'Snapdeal.com': 109, 'Amazon.in': 104, 'Flipkart.com': 60, 'Paytm.com': 53, 'Myntra.com': 7})

# %% [markdown]
# The column 'Limited mode of payment on most products (promotion, sales period)' tells us about customers opinion on which app or website gives limited mode of payment on most of the products, from the plot about we can observe that most of the customers say that snapdeal.com (109) gives limited mode of paymenyt on most of the products, Amzon.in stand almost near by with 104 votes, Myntra.com get the least votes in this aspect

# %%
L66=[i.split(',',-1)for i in df11['Longer delivery period']]
FL66=[item for sublist in L66 for item in sublist]
print(len(FL66))
FL66=[x.strip(' ') for x in FL66]
print(Counter(FL66))
plt.figure(figsize=(10,5))
plt.title('Longer delivery period')
plt.hist(FL66);
plt.show()
# Out:
# 295
# Counter({'Paytm.com': 98, 'Snapdeal.com': 90, 'Flipkart.com': 44, 'Amazon.in': 37, 'Myntra.com': 26})

# %% [markdown]
# The column 'Longer delivery period' tells us about according to customers who takes a longer time to deliver the products, from the above plot we can observe that most of the customers have voted to paytm.com (98) that they take more time to deliver the product compared to others, least votes are given for Myntra.com (26)

# %%
L67=[i.split(',',-1)for i in df11['Change in website/Application design']]
FL67=[item for sublist in L67 for item in sublist]
print(len(FL67))
FL67=[x.strip(' ') for x in FL67]
print(Counter(FL67))
plt.figure(figsize=(10,5))
plt.title('Change in website/Application design')
plt.hist(FL67);
plt.show()
# Out:
# 321
# Counter({'Amazon.in': 141, 'Flipkart.com': 72, 'Paytm.com': 63, 'Myntra.com': 37, 'Snapdeal.com': 8})

# %% [markdown]
# The column 'Change in website/Application design' tells us about which e-retail store does changes in websites/Application frequently, from the above plot we can observe that customers have voted that Amzon.in (141) makes changes in website/Application designs frequently, least votes are given for Snapdeal.com (8)

# %%
L68=[i.split(',',-1)for i in df11['Frequent disruption when moving from one page to another']]
FL68=[item for sublist in L68 for item in sublist]
print(len(FL68))
FL68=[x.strip(' ') for x in FL68]
print(Counter(FL68))
plt.figure(figsize=(10,5))
plt.title('Frequent disruption when moving from one page to another')
plt.hist(FL68);
plt.show()
# Out:
# 319
# Counter({'Amazon.in': 78, 'Snapdeal.com': 74, 'Myntra.com': 66, 'Flipkart.com': 62, 'Paytm.com': 39})

# %% [markdown]
# The column 'Frequent disruption when moving from one page to another' tells us about according to customers which App or website creates disruptions frequently while moving from one page to another, from the above plot we can observe that customers ahve given almost equal votes to Amzon.in (78) and Snapdeal.com (74) that they create frequent disruptions while moving from one page to another, least votes are given for Paytem.com (39)

# %%
L69=[i.split(',',-1)for i in df11['Website is as efficient as before']]
FL69=[item for sublist in L69 for item in sublist]
print(len(FL69))
FL69=[x.strip(' ') for x in FL69]
print(Counter(FL69))
plt.figure(figsize=(10,5))
plt.title('Website is as efficient as before')
plt.hist(FL69);
plt.show()
# Out:
# 396
# Counter({'Amazon.in': 182, 'Flipkart.com': 117, 'Paytm.com': 58, 'Snapdeal.com': 25, 'Myntra.com': 14})

# %% [markdown]
# The column 'Website is as efficient as before' tells us about according to customers which website is working efficietly as it was before, from the above plot we can observe that customers gave maximum votes to Amazon.in (182) that it works efficiently as before and least votes are given to Myntra (14)

# %%
L70=[i.split(',',-1)for i in df11['Which of the Indian online retailer would you recommend to a friend?']]
FL70=[item for sublist in L70 for item in sublist]
print(len(FL70))
FL70=[x.strip(' ') for x in FL70]
print(Counter(FL70))
plt.figure(figsize=(10,5))
plt.title('Which of the Indian online retailer would you recommend to a friend?')
plt.hist(FL70);
plt.show()
# Out:
# 477
# Counter({'Amazon.in': 219, 'Flipkart.com': 127, 'Myntra.com': 76, 'Paytm.com': 44, 'snapdeal.com': 11})

# %% [markdown]
# The column 'Which of the Indian online retailer would you recommend to a friend?' tells us about which online retailer customer would recommend to their friends, Maximum number of customers are telling that they would recommend Amazon.in (219) to their friends and laest votes are given to Snapdeal.com (11)

# %% [markdown]
# # We can do further EDA considering Coded data

# %%
dfC.columns=dfC.columns.str.replace('\t', '')
dfC.columns = dfC.columns.str.strip()

# %%
dfC.shape
# Out:
# (269, 71)

# %%
dfC.isnull().sum()
# Out:
# 1Gender of respondent                                                                                         0
# 2 How old are you?                                                                                            0
# 3 Which city do you shop online from?                                                                         0
# 4 What is the Pin Code of where you shop online from?                                                         0
# 5 Since How Long You are Shopping Online ?                                                                    0
# 6 How many times you have made an online purchase in the past 1 year?                                         0
# 7 How do you access the internet while shopping on-line?                                                      0
# 8 Which device do you use to access the online shopping?                                                      0
# ...

# %%
sns.heatmap(dfC.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap and description we can observe that there are no missing values is datasets

# %%
pd.set_option('display.max_columns', None)
dfC.describe()
# Out:
#        1Gender of respondent  2 How old are you?  \
# count             269.000000          269.000000
# mean                0.669145            2.959108
# std                 0.471398            1.066012
# min                 0.000000            1.000000
# 25%                 0.000000            2.000000
# 50%                 1.000000            3.000000
# 75%                 1.000000            4.000000
# max                 1.000000            5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %% [markdown]
# Key Observations :
# 1. We can see that mean is greater than median (50th percentile) in the columns
#    * 4 What is the Pin Code of where you shop online from?
#    * 8 Which device do you use to access the online shopping?
#    * 11 What browser do you run on your device to access the website?
#    * 12 Which channel did you follow to arrive at your favorite online store for the first time?
#    * 15 What is your preferred payment Option?
#    * 17 Why did you abandon the “Bag”, “Shopping Cart”?
#    Hence right skewness is present in these columns, The same we can observe from the below data as well

# %%
#Visualization of data having right skewness looks like below
sns.histplot(dfC['4 What is the Pin Code of where you shop online from?'],bins=20)
# Out:
# <AxesSubplot:xlabel='4 What is the Pin Code of where you shop online from?', ylabel='Count'>

# %% [markdown]
# We can observe that mean is less than median (50th percentile) in the columns
#    * 1Gender of respondent
#    * 5 Since How Long You are Shopping Online ?
#    * 9 What is the screen size of your mobile device?
#    * 14 How much time do you explore the e- retail store before making a purchase decision?
#    * 18 The content on the website must be easy to read and understand
#    * 19 Information on similar product to the one highlighted  is important for product comparison
#    * 20 Complete information on listed seller and product being offered is important for purchase decision.
#    * 21 All relevant information on listed products must be stated clearly
#    * 22 Ease of navigation in website
#    * 23 Loading and processing speed
#    * 24 User friendly Interface of the website
#    * 25 Convenient Payment methods
#    * 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time
#    * 27 Empathy (readiness to assist with queries) towards the customers
#    * 28 Being able to guarantee the privacy of the customer
#    * 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)
#    * 30 Online shopping gives monetary benefit and discounts
#    * 31 Enjoyment is derived from shopping online
#    * 32 Shopping online is convenient and flexible
#    * 33 Return and replacement policy of the e-tailer is important for purchase decision
#    * 34 Gaining access to loyalty programs is a benefit of shopping online
#    * 35 Displaying quality Information on the website improves satisfaction of customers
#    * 36 User derive satisfaction while shopping on a good quality website or application
#    * 37 Net Benefit derived from shopping online can lead to users satisfaction
#    * 38 User satisfaction cannot exist without trust
#    * 39 Offering a wide variety of listed product in several category
#    * 40 Provision of complete and relevant product information
#    * 41 Monetary savings
#    * 46 Shopping on the website helps you fulfill certain roles
# Hence we there is left skewness present in these respective columns

# %%
#Visualization of data having left skewness looks like below
sns.histplot(dfC['9 What is the screen size of your mobile device?'],bins=20)
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?', ylabel='Count'>

# %%
dfC.skew()
# Out:
# 1Gender of respondent                                                                                        -0.723007
# 2 How old are you?                                                                                            0.063243
# 4 What is the Pin Code of where you shop online from?                                                         1.748322
# 5 Since How Long You are Shopping Online ?                                                                   -0.554705
# 6 How many times you have made an online purchase in the past 1 year?                                         0.227755
# 7 How do you access the internet while shopping on-line?                                                      0.567694
# 8 Which device do you use to access the online shopping?                                                      1.121438
# 9 What is the screen size of your mobile device?                                                             -1.421577
# ...

# %% [markdown]
# 2. We can observe that there is a huge gap between 75th percentile and max in the columns
#    * 4 What is the Pin Code of where you shop online from?
#    * 8 Which device do you use to access the online shopping?
#    * 11 What browser do you run on your device to access the website?
#    * 12 Which channel did you follow to arrive at your favorite online store for the first time?
#    * 16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?
# Hence there are outliers present in those columns data, the same we can observe from the below plots as well

# %%
plt.figure(figsize = (12,5))
sns.boxplot(data=dfC[["4 What is the Pin Code of where you shop online from?", "8 Which device do you use to access the online shopping?"]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=dfC["12 Which channel did you follow to arrive at your favorite online store for the first time?"])
# Out:
# <AxesSubplot:>

# %%
#Since the number of columns are high it is difficult to plot heatmap on single page, we can split the coded data into 2 part and then plot the map

# %%
dfcorr1=dfC.iloc[:,0:25]
dfcorr1.head(2)
# Out:
#    1Gender of respondent  2 How old are you?  \
# 0                      0                   3
# 1                      1                   2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# 1                                           5
#
#    6 How many times you have made an online purchase in the past 1 year?  \
# 0                                                  4
# 1                                                  5
#
#    7 How do you access the internet while shopping on-line?  \
# 0                                                  4
# 1                                                  2
#
# ...

# %%
dfcorr2=dfC.iloc[:,25:47]
dfcorr2.head(2)
# Out:
#    26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time  \
# 0                                                  2
# 1                                                  5
#
#    27 Empathy (readiness to assist with queries) towards the customers  \
# 0                                                  5
# 1                                                  5
#
#    28 Being able to guarantee the privacy of the customer  \
# 0                                                  4
# 1                                                  5
#
#    29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)  \
# 0                                                  4
# 1                                                  5
#
#    30 Online shopping gives monetary benefit and discounts  \
# 0                                                  3
# 1                                                  5
#
# ...

# %%
plt.figure(figsize = (16,9))
sns.heatmap(dfcorr1.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heat map we can observe that :
# * 'Convenient payment method' has a good correlation with 'user friendly inteface of the website', 'Loading and processing speed' and 'The content on the website must be easy to read and understand'
# * '21 All relevant information on listed products must be stated clearly' has good correlation with '18 The content on the website must be easy to read and understand'

# %%
plt.figure(figsize = (16,9))
sns.heatmap(dfcorr2.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap we can observe that :
# * '28 Being able to guarantee the privacy of the customer' has good correlation with '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time' and '27 Empathy (readiness to assist with queries) towards the customers'
# * '27 Empathy (readiness to assist with queries) towards the customers' has a good correlation with '38 User satisfaction cannot exist without trust'
