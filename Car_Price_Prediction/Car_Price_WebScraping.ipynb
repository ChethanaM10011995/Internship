# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Location = Bengaluru

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=4709&pinId=560001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_url=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_url.append(i.get_attribute("href"))

# %%
len(Product_url)
# Out:
# 836

# %%
Product_url
# Out:
# ['https://www.cars24.com/buy-used-maruti-alto-800-2013-cars-bengaluru-10287079771/',
#  'https://www.cars24.com/buy-used-maruti-ritz-2011-cars-bengaluru-10251295734/',
#  'https://www.cars24.com/buy-used-hyundai-aura-2022-cars-bengaluru-10235294729/',
#  'https://www.cars24.com/buy-used-hyundai-i20-2014-cars-bengaluru-10242293748/',
#  'https://www.cars24.com/buy-used-maruti-swift-2012-cars-bengaluru-10211895766/',
#  'https://www.cars24.com/buy-used-maruti-ritz-2011-cars-bengaluru-10250894725/',
#  'https://www.cars24.com/buy-used-maruti-ertiga-2019-cars-bengaluru-10288478797/',
#  'https://www.cars24.com/buy-used-hyundai-i10-2010-cars-bengaluru-10275697703/',
#  'https://www.cars24.com/buy-used-hyundai-i10-2011-cars-bengaluru-10229693701/',
#  'https://www.cars24.com/buy-used-hyundai-i20-2010-cars-bengaluru-10209670791/',
#  'https://www.cars24.com/buy-used-maruti-swift-dzire-2016-cars-bengaluru-10266490748/',
# ...

# %%
Brand=[]
Model=[]
Variant=[]
Details=[]
Location=[]
Price=[]

# %%
for url in Product_url:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        Model.append(model.text)
    except NoSuchElementException:
        Model.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        Details.append(details.text)
    except NoSuchElementException:
        Details.append('-')
        
    
    try:
        location=driver.find_element(By.XPATH,'//p[@class="_2NHUv"]')
        Location.append(location.text)
    except NoSuchElementException:
        Location.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')

# %%
print(len(Brand),len(Model),len(Variant),len(Details),len(Location),len(Price))
# Out:
# 836 836 836 836 836 836

# %%
Model
# Out:
# ['2013 Maruti Alto 800 LXI MANUAL',
#  '2011 Maruti Ritz VXI MANUAL',
#  '2022 Hyundai AURA SX (O) MT',
#  '2014 Hyundai i20 MAGNA O 1.2 MANUAL',
#  '2012 Maruti Swift ZXI MANUAL',
#  '2011 Maruti Ritz VXI MANUAL',
#  '2019 Maruti Ertiga ZXI SMART HYBRID AT AUTOMATIC',
#  '2010 Hyundai i10 SPORTZ 1.2 MANUAL',
#  '2011 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  '2010 Hyundai i20 MAGNA O 1.2 MANUAL',
#  '2016 Maruti Swift Dzire VXI MANUAL',
#  '2021 Nissan MAGNITE XL Turbo CVT',
#  '2019 Maruti New Wagon-R VXI 1.2L MANUAL',
#  '2021 Tata Safari XM 2.0 KRYOTEC MANUAL',
#  '2018 Maruti Ertiga ZDI PLUS SHVS MANUAL',
#  '2011 Hyundai Santro Xing GLS MANUAL',
#  '2011 Maruti Ritz VXI MANUAL',
#  '2021 Hyundai ALCAZAR 2.0 SIGNATURE (O) AT 6STR',
#  '2010 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  '2022 Nissan MAGNITE XV CVT TURBO',
#  '2021 Maruti Swift ZXI + AMT AUTOMATIC',
#  '2011 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  '2013 Maruti Alto 800 LXI MANUAL',
# ...

# %%
driver.close()

# %%
Model.remove("-")

# %%
len(Model)
# Out:
# 824

# %%
Model
# Out:
# ['2013 Maruti Alto 800 LXI MANUAL',
#  '2011 Maruti Ritz VXI MANUAL',
#  '2022 Hyundai AURA SX (O) MT',
#  '2014 Hyundai i20 MAGNA O 1.2 MANUAL',
#  '2012 Maruti Swift ZXI MANUAL',
#  '2011 Maruti Ritz VXI MANUAL',
#  '2019 Maruti Ertiga ZXI SMART HYBRID AT AUTOMATIC',
#  '2010 Hyundai i10 SPORTZ 1.2 MANUAL',
#  '2011 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  '2010 Hyundai i20 MAGNA O 1.2 MANUAL',
#  '2016 Maruti Swift Dzire VXI MANUAL',
#  '2021 Nissan MAGNITE XL Turbo CVT',
#  '2019 Maruti New Wagon-R VXI 1.2L MANUAL',
#  '2021 Tata Safari XM 2.0 KRYOTEC MANUAL',
#  '2018 Maruti Ertiga ZDI PLUS SHVS MANUAL',
#  '2011 Hyundai Santro Xing GLS MANUAL',
#  '2011 Maruti Ritz VXI MANUAL',
#  '2021 Hyundai ALCAZAR 2.0 SIGNATURE (O) AT 6STR',
#  '2010 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  '2022 Nissan MAGNITE XV CVT TURBO',
#  '2021 Maruti Swift ZXI + AMT AUTOMATIC',
#  '2011 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  '2013 Maruti Alto 800 LXI MANUAL',
# ...

# %%
Model1=[item.split(' ',2)[2] for item in Model]
Model1
# Out:
# ['Alto 800 LXI MANUAL',
#  'Ritz VXI MANUAL',
#  'AURA SX (O) MT',
#  'i20 MAGNA O 1.2 MANUAL',
#  'Swift ZXI MANUAL',
#  'Ritz VXI MANUAL',
#  'Ertiga ZXI SMART HYBRID AT AUTOMATIC',
#  'i10 SPORTZ 1.2 MANUAL',
#  'i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  'i20 MAGNA O 1.2 MANUAL',
#  'Swift Dzire VXI MANUAL',
#  'MAGNITE XL Turbo CVT',
#  'New Wagon-R VXI 1.2L MANUAL',
#  'Safari XM 2.0 KRYOTEC MANUAL',
#  'Ertiga ZDI PLUS SHVS MANUAL',
#  'Santro Xing GLS MANUAL',
#  'Ritz VXI MANUAL',
#  'ALCAZAR 2.0 SIGNATURE (O) AT 6STR',
#  'i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  'MAGNITE XV CVT TURBO',
#  'Swift ZXI + AMT AUTOMATIC',
#  'i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  'Alto 800 LXI MANUAL',
#  'Swift VXI MANUAL',
#  'Ritz VXI MANUAL',
#  'Swift VXI MANUAL',
#  'Kwid 1.0 CLIMBER OPT MANUAL',
#  'Swift Dzire ZXI 1.2 BS IV MANUAL',
#  'i20 MAGNA O 1.2 MANUAL',
#  'S PRESSO VXI (O) CNG MANUAL',
#  'i10 SPORTZ 1.2 MANUAL',
#  'Creta 1.6 SX VTVT (O) EXECUTIVE MANUAL',
#  'Jazz 1.2 SELECT I VTEC MANUAL',
# ...

# %%
Automatic=[item.split(' ')[-1] for item in Model]
Automatic
# Out:
# ['MANUAL',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'CVT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  '6STR',
#  'MANUAL',
#  'TURBO',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MT',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  '1.0',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  '1.0',
#  '1.0',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'TONE',
# ...

# %%
Km=[item.split(' ')[0] for item in Details]

# %%
len(Km)
# Out:
# 826

# %%
Km.remove("-")
len(Km)
# Out:
# 824

# %%
Location = ['Bengaluru'] * 824

# %%
Variant.remove("-")
len(Variant)
# Out:
# 824

# %%
len(Model1)
# Out:
# 824

# %%
len(Automatic)
# Out:
# 824

# %%
Man_year=[item.split(' ')[0] for item in Model]
Man_year
# Out:
# ['2013',
#  '2011',
#  '2022',
#  '2014',
#  '2012',
#  '2011',
#  '2019',
#  '2010',
#  '2011',
#  '2010',
#  '2016',
#  '2021',
#  '2019',
#  '2021',
#  '2018',
#  '2011',
#  '2011',
#  '2021',
#  '2010',
#  '2022',
#  '2021',
#  '2011',
#  '2013',
#  '2012',
#  '2010',
#  '2021',
#  '2021',
#  '2013',
#  '2010',
#  '2021',
#  '2009',
#  '2019',
#  '2012',
#  '2010',
#  '2012',
#  '2010',
#  '2011',
#  '2021',
#  '2020',
#  '2021',
#  '2012',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2011',
#  '2018',
#  '2010',
#  '2010',
#  '2021',
#  '2014',
#  '2019',
#  '2012',
#  '2010',
#  '2021',
#  '2020',
#  '2021',
#  '2012',
#  '2010',
#  '2012',
#  '2020',
#  '2016',
#  '2019',
#  '2016',
#  '2018',
#  '2021',
#  '2021',
#  '2012',
#  '2021',
#  '2020',
#  '2020',
#  '2014',
#  '2021',
#  '2019',
#  '2018',
#  '2012',
#  '2022',
#  '2013',
#  '2021',
#  '2019',
#  '2010',
#  '2012',
#  '2016',
#  '2017',
#  '2012',
#  '2015',
#  '2017',
#  '2013',
#  '2012',
#  '2020',
# ...

# %%
len(Man_year)
# Out:
# 824

# %%
Details
# Out:
# ['15,999 kmPetrol1st OwnerKA-03',
#  '28,022 kmPetrol1st OwnerKA-03',
#  '3,382 kmPetrol1st OwnerKA-05',
#  '55,910 kmPetrol1st OwnerKA-03',
#  '47,003 kmPetrol1st OwnerKA-04',
#  '40,032 kmPetrol1st OwnerKA-03',
#  '34,347 kmPetrol1st OwnerKA-03',
#  '76,103 kmPetrol1st OwnerKA-51',
#  '29,295 kmPetrol2nd OwnerKA-41',
#  '61,270 kmPetrol1st OwnerKA-51',
#  '32,337 kmPetrol1st OwnerKA-03',
#  '6,264 kmPetrol1st OwnerKA-03',
#  '3,455 kmPetrol1st OwnerKA-53',
#  '9,682 kmDiesel2nd OwnerKA-05',
#  '24,130 kmDiesel1st OwnerKA-03',
#  '91,282 kmPetrol1st OwnerKA-03',
#  '99,832 kmPetrol1st OwnerKA-04',
#  '3,044 kmPetrol1st OwnerKA-02',
#  '71,534 kmPetrol2nd OwnerKA-51',
#  '1,975 kmPetrol1st OwnerKA-01',
#  '15,637 kmPetrol2nd OwnerKA-03',
#  '50,950 kmPetrol3rd OwnerKA-01',
#  '32,408 kmPetrol1st OwnerKA-51',
#  '76,615 kmPetrol2nd OwnerKA-03',
#  '75,030 kmPetrol1st OwnerKA-19',
#  '31,794 kmPetrol1st OwnerKA-67',
#  '4,205 kmPetrol1st OwnerKA-51',
# ...

# %%
Details.remove("-")

# %%
len(Details)
# Out:
# 824

# %%
a=[item.split(' km')[1] for item in Details]
a
# Out:
# ['Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-05',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-04',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-51',
#  'Petrol2nd OwnerKA-41',
#  'Petrol1st OwnerKA-51',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-53',
#  'Diesel2nd OwnerKA-05',
#  'Diesel1st OwnerKA-03',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-04',
#  'Petrol1st OwnerKA-02',
#  'Petrol2nd OwnerKA-51',
#  'Petrol1st OwnerKA-01',
#  'Petrol2nd OwnerKA-03',
#  'Petrol3rd OwnerKA-01',
#  'Petrol1st OwnerKA-51',
#  'Petrol2nd OwnerKA-03',
#  'Petrol1st OwnerKA-19',
#  'Petrol1st OwnerKA-67',
#  'Petrol1st OwnerKA-51',
#  'Petrol1st OwnerKA-04',
#  'Petrol2nd OwnerKA-01',
#  'Petrol + CNG1st OwnerKA-27',
#  'Petrol2nd OwnerKA-53',
#  'Petrol2nd OwnerKA-51',
#  'Petrol1st OwnerKA-03',
#  'Petrol1st OwnerKA-03',
#  'Petrol2nd OwnerKA-03',
#  'Petrol1st OwnerKA-03',
# ...

# %%
Fuel=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
Owner=[item.split(' ')[0] for item in b]

# %%
len(Price)
# Out:
# 826

# %%
Price.remove("-")

# %%
Brand.remove("-")

# %%
len(Price)
# Out:
# 824

# %%
Price1=[item.split('\n₹')[1] for item in Price]

# %%
df=pd.DataFrame({'Brand':Brand,'Model':Model1,'Automatic':Automatic,'Variant':Variant,'Km':Km,'Location':Location,'Man_year':Man_year,'Fuel':Fuel,'Owner':Owner,'Price':Price1})
df
# Out:
#        Brand                                Model  Automatic  \
# 0     Maruti                  Alto 800 LXI MANUAL     MANUAL
# 1     Maruti                      Ritz VXI MANUAL     MANUAL
# 2    Hyundai                       AURA SX (O) MT         MT
# 3    Hyundai               i20 MAGNA O 1.2 MANUAL     MANUAL
# 4     Maruti                     Swift ZXI MANUAL     MANUAL
# ..       ...                                  ...        ...
# 819  Hyundai  NEW SANTRO 1.1 SPORTS AMT AUTOMATIC  AUTOMATIC
# 820   Maruti            Celerio ZXI AMT AUTOMATIC  AUTOMATIC
# 821  Hyundai           i20 SPORTZ 1.2 VTVT MANUAL     MANUAL
# 822    Honda        Civic 1.8V MT SUN ROOF MANUAL     MANUAL
# 823  Hyundai           Elite i20 MAGNA 1.2 MANUAL     MANUAL
#
#                       Variant      Km   Location Man_year   Fuel Owner  \
# 0                  LXI MANUAL  15,999  Bengaluru     2013  Petro   1st
# 1                  VXI MANUAL  28,022  Bengaluru     2011  Petro   1st
# ...

# %%
df.to_csv('Car_Pricing1.csv')

# %% [markdown]
# # Location = Hyderabad

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=3686&pinId=500001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_url1=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_url1.append(i.get_attribute("href"))

# %%
del Product_url1[-10:]

# %%
len(Product_url1)
# Out:
# 466

# %%
BrandH=[]
ModelH=[]
VariantH=[]
DetailsH=[]
PriceH=[]

# %%
for url in Product_url1:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandH.append(brand.text)
    except NoSuchElementException:
        BrandH.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelH.append(model.text)
    except NoSuchElementException:
        ModelH.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantH.append(variant.text)
    except NoSuchElementException:
        VariantH.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsH.append(details.text)
    except NoSuchElementException:
        DetailsH.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceH.append(price.text)
    except NoSuchElementException:
        PriceH.append('-')

# %%
BrandH.remove("-")

# %%
len(BrandH)
# Out:
# 465

# %%
ModelH.remove('-')

# %%
Model2=[item.split(' ',2)[2] for item in ModelH]
Model2
# Out:
# ['Swift VXI MANUAL',
#  'Go Plus T MANUAL',
#  'Swift VXI MANUAL',
#  'Swift ZXI+ DUAL TONE',
#  'Kwid RXL MANUAL',
#  'i10 SPORTZ 1.2 AT KAPPA2 AUTOMATIC',
#  'City S MT PETROL MANUAL',
#  'Swift VDI MANUAL',
#  'MAGNITE XV PRM. TURBO . MT PETROL',
#  'Alto 800 LXI MANUAL',
#  'i10 SPORTZ 1.2 AT KAPPA2 AUTOMATIC',
#  'Celerio ZXI MANUAL',
#  'i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  'Celerio ZXI AMT AUTOMATIC',
#  'Alto 800 LXI MANUAL',
#  'Swift VXI AMT AUTOMATIC',
#  'i10 SPORTZ 1.2 AT KAPPA2 AUTOMATIC',
#  'Celerio VXI (O) AMT AUTOMATIC',
#  'Swift Dzire VXI MANUAL',
#  'Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL',
#  'i10 SPORTZ 1.2 AT KAPPA2 AUTOMATIC',
#  'Creta 1.6 SX (O) CRDI MANUAL',
#  'Alto 800 LXI MANUAL',
#  'Celerio ZXI+ MANUAL',
#  'Polo COMFORTLINE 1.2L PETROL MANUAL',
#  'Polo Trendline 1.0 L Petrol MANUAL',
#  'Swift ZXI MANUAL',
#  'Alto 800 LXI MANUAL',
#  'i10 MAGNA 1.1 IRDE2 MANUAL',
#  'Polo COMFORTLINE 1.0 PETROL MANUAL',
#  'Amaze 1.2 SMT I VTEC MANUAL',
# ...

# %%
len(Model2)
# Out:
# 465

# %%
Automatic1=[item.split(' ')[-1] for item in ModelH]
Automatic1
# Out:
# ['MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'TONE',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'PETROL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'IMT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'DSG',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'HYBRID',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
# ...

# %%
VariantH.remove('-')

# %%
Man_year1=[item.split(' ')[0] for item in ModelH]
Man_year1
# Out:
# ['2020',
#  '2017',
#  '2020',
#  '2022',
#  '2019',
#  '2012',
#  '2010',
#  '2015',
#  '2021',
#  '2014',
#  '2012',
#  '2017',
#  '2012',
#  '2015',
#  '2014',
#  '2019',
#  '2012',
#  '2018',
#  '2013',
#  '2016',
#  '2012',
#  '2016',
#  '2013',
#  '2022',
#  '2016',
#  '2020',
#  '2014',
#  '2015',
#  '2015',
#  '2019',
#  '2016',
#  '2014',
#  '2016',
#  '2014',
#  '2015',
#  '2016',
#  '2014',
#  '2013',
#  '2021',
#  '2013',
#  '2014',
#  '2018',
#  '2018',
#  '2017',
#  '2015',
#  '2019',
#  '2015',
#  '2012',
#  '2017',
#  '2021',
#  '2012',
#  '2017',
#  '2014',
#  '2014',
#  '2022',
#  '2015',
#  '2014',
#  '2015',
#  '2021',
#  '2021',
#  '2011',
#  '2014',
#  '2020',
#  '2022',
#  '2012',
#  '2015',
#  '2017',
#  '2017',
#  '2017',
#  '2018',
#  '2022',
#  '2016',
#  '2014',
#  '2018',
#  '2018',
#  '2017',
#  '2019',
#  '2022',
#  '2013',
#  '2016',
#  '2014',
#  '2016',
#  '2019',
#  '2017',
#  '2022',
#  '2016',
#  '2012',
#  '2021',
#  '2020',
#  '2013',
# ...

# %%
len(Man_year1)
# Out:
# 465

# %%
DetailsH.remove('-')
Km1=[item.split(' ')[0] for item in DetailsH]
len(Km1)
# Out:
# 465

# %%
LocationH = ['Hyderabad'] * 465

# %%
a=[item.split(' km')[1] for item in DetailsH]
Fuel1=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
Owner1=[item.split(' ')[0] for item in b]

# %%
Price1=[item.split('\n₹')[1] for item in PriceH]
len(Price1)
# Out:
# 465

# %%
df1=pd.DataFrame({'Brand':BrandH,'Model':Model2,'Automatic':Automatic1,'Variant':VariantH,'Km':Km1,'Location':LocationH,'Man_year':Man_year1,'Fuel':Fuel1,'Owner':Owner1,'Price':Price1})
df1
# Out:
#           Brand                                 Model  Automatic  \
# 0        Maruti                      Swift VXI MANUAL     MANUAL
# 1        Datsun                      Go Plus T MANUAL     MANUAL
# 2        Maruti                      Swift VXI MANUAL     MANUAL
# 3        Maruti                  Swift ZXI+ DUAL TONE       TONE
# 4       Renault                       Kwid RXL MANUAL     MANUAL
# ..          ...                                   ...        ...
# 460        Tata    NEXON XZA+ 1.5 Dual Tone AUTOMATIC  AUTOMATIC
# 461      Maruti            Baleno ZETA 1.2 K12 MANUAL     MANUAL
# 462  Volkswagen  Ameo HIGHLINE PLUS DSG 1.5 AUTOMATIC  AUTOMATIC
# 463    Mahindra                   MARAZZO M 6 + 8 STR        STR
# 464        Ford    FREESTYLE TITANIUM 1.5 TDCI MANUAL     MANUAL
#
#                              Variant      Km   Location Man_year   Fuel Owner  \
# 0                         VXI MANUAL  10,056  Hyderabad     2020  Petro   2nd
# ...

# %%
df1.to_csv('Car_Pricing2.csv')

# %% [markdown]
# # Location = NewDelhi

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_url2=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_url2.append(i.get_attribute("href"))
    
len(Product_url2)
# Out:
# 965

# %%
del Product_url2[-10:]
len(Product_url2)
# Out:
# 955

# %%
BrandND=[]
ModelND=[]
VariantND=[]
DetailsND=[]
PriceND=[]

# %%
for url in Product_url2:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandND.append(brand.text)
    except NoSuchElementException:
        BrandND.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelND.append(model.text)
    except NoSuchElementException:
        ModelND.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantND.append(variant.text)
    except NoSuchElementException:
        VariantND.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsND.append(details.text)
    except NoSuchElementException:
        DetailsND.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceND.append(price.text)
    except NoSuchElementException:
        PriceND.append('-')

# %%
len(PriceND)
# Out:
# 955

# %%
PriceND1=[s for s in PriceND if s != '-']
len(PriceND1)
# Out:
# 842

# %%
BrandND1=[s for s in BrandND if s != '-']
ModelND1=[s for s in ModelND if s != '-']
VariantND1=[s for s in VariantND if s != '-']
DetailsND1=[s for s in DetailsND if s != '-']

# %%
print(len(BrandND1),len(ModelND1),len(VariantND1),len(DetailsND1))
# Out:
# 842 842 842 842

# %%
ModelND2=[item.split(' ',2)[2] for item in ModelND1]
ModelND2
# Out:
# ['AURA E MT 1.2 KAPPA MANUAL',
#  'Swift LXI MANUAL',
#  'Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL',
#  'Grand i10 MAGNA 1.2 KAPPA VTVT MANUAL',
#  'Swift LXI MANUAL',
#  'Swift LXI MANUAL',
#  'Swift LXI MANUAL',
#  'Wagon R 1.0 LXI MANUAL',
#  'Benz C Class C 200 AVANTGARDE AUTOMATIC',
#  'SELTOS GTX + AT PETROL AUTOMATIC',
#  'Grand i10 MAGNA 1.2 VTVT MANUAL',
#  'AURA S 1.2 Kappa MT MANUAL',
#  'Kwid Neotech 1.0 EasyR AUTOMATIC',
#  'Wagon R 1.0 VXI MANUAL',
#  'NEW SANTRO SPORTZ EXECUTIVE CNG MANUAL',
#  'CARENS LUXURY 1.4G MT 7STR',
#  'Swift LXI MANUAL',
#  'i10 MAGNA 1.1 IRDE2 MANUAL',
#  'ALTROZ XM+ 1.2 RTN',
#  'Eon ERA PLUS MANUAL',
#  'Swift LXI MANUAL',
#  'SELTOS GTX 1.4 GDI AT PETROL AUTOMATIC',
#  'Kiger RXE 1.0 MT',
#  'Swift LXI MANUAL',
#  'Kiger RXZ 1.0 MT',
#  'VENUE S Plus MT 1.2 Kappa MANUAL',
#  'Alto K10 VXI MANUAL',
#  'NEW I20 Asta 1.0 GDI Turbo IMT',
#  'SELTOS HTK PLUS AT 1.5 DIESEL AUTOMATIC',
#  'New Wagon-R LXI 1.0 L MANUAL',
# ...

# %%
AutomaticND=[item.split(' ')[-1] for item in ModelND1]
AutomaticND
# Out:
# ['MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  '7STR',
#  'MANUAL',
#  'MANUAL',
#  'RTN',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MT',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'IMT',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  '1.2',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  '1.0',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'AT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'IMT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
# ...

# %%
Man_yearND=[item.split(' ')[0] for item in ModelND1]
Man_yearND
# Out:
# ['2021',
#  '2019',
#  '2018',
#  '2018',
#  '2020',
#  '2020',
#  '2019',
#  '2013',
#  '2014',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2011',
#  '2022',
#  '2022',
#  '2020',
#  '2014',
#  '2021',
#  '2012',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2011',
#  '2021',
#  '2020',
#  '2021',
#  '2012',
#  '2021',
#  '2020',
#  '2018',
#  '2021',
#  '2021',
#  '2011',
#  '2020',
#  '2009',
#  '2019',
#  '2010',
#  '2014',
#  '2020',
#  '2021',
#  '2020',
#  '2010',
#  '2011',
#  '2019',
#  '2021',
#  '2021',
#  '2011',
#  '2011',
#  '2011',
#  '2014',
#  '2015',
#  '2020',
#  '2014',
#  '2015',
#  '2014',
#  '2019',
#  '2022',
#  '2015',
#  '2020',
#  '2014',
#  '2015',
#  '2018',
#  '2022',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2020',
#  '2013',
#  '2020',
#  '2020',
#  '2015',
#  '2021',
#  '2020',
#  '2013',
#  '2017',
#  '2021',
#  '2019',
#  '2021',
#  '2022',
#  '2012',
#  '2022',
#  '2021',
#  '2020',
#  '2011',
#  '2016',
# ...

# %%
KmND=[item.split(' ')[0] for item in DetailsND1]
len(KmND)
# Out:
# 842

# %%
LocationND = ['New Delhi'] * 842

# %%
a=[item.split(' km')[1] for item in DetailsND1]
FuelND=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
OwnerND=[item.split(' ')[0] for item in b]

# %%
PriceND2=[item.split('\n₹')[1] for item in PriceND1]
len(PriceND2)
# Out:
# 842

# %%
df2=pd.DataFrame({'Brand':BrandND1,'Model':ModelND2,'Automatic':AutomaticND,'Variant':VariantND1,'Km':KmND,'Location':LocationND,'Man_year':Man_yearND,'Fuel':FuelND,'Owner':OwnerND,'Price':PriceND2})
df2
# Out:
#        Brand                                   Model Automatic  \
# 0    Hyundai              AURA E MT 1.2 KAPPA MANUAL    MANUAL
# 1     Maruti                        Swift LXI MANUAL    MANUAL
# 2    Hyundai  Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL    MANUAL
# 3    Hyundai   Grand i10 MAGNA 1.2 KAPPA VTVT MANUAL    MANUAL
# 4     Maruti                        Swift LXI MANUAL    MANUAL
# ..       ...                                     ...       ...
# 837   Maruti          Ertiga VXI SMART HYBRID MANUAL    MANUAL
# 838  Renault       Kiger RXZ CVT 1.0 TURBO DUAL TONE      TONE
# 839     Tata                TIGOR Revotron XE MANUAL    MANUAL
# 840  Hyundai         Grand i10 MAGNA 1.2 VTVT MANUAL    MANUAL
# 841   Maruti                        Swift VXI MANUAL    MANUAL
#
#                           Variant      Km   Location Man_year   Fuel Owner  \
# 0           E MT 1.2 KAPPA MANUAL   1,125  New Delhi     2021  Petro   1st
# ...

# %%
df2.to_csv('Car_Pricing3.csv')

# %%
driver.close()

# %% [markdown]
# # Location = Noida

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=134&pinId=201301')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_urlN=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_urlN.append(i.get_attribute("href"))
    
len(Product_urlN)
# Out:
# 962

# %%
del Product_urlN[-10:]
len(Product_urlN)
# Out:
# 952

# %%
BrandN=[]
ModelN=[]
VariantN=[]
DetailsN=[]
PriceN=[]

# %%
for url in Product_urlN:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandN.append(brand.text)
    except NoSuchElementException:
        BrandN.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelN.append(model.text)
    except NoSuchElementException:
        ModelN.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantN.append(variant.text)
    except NoSuchElementException:
        VariantN.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsN.append(details.text)
    except NoSuchElementException:
        DetailsN.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceN.append(price.text)
    except NoSuchElementException:
        PriceN.append('-')

# %%
ModelN1=[item.split(' ',2)[2] for item in ModelN]
ModelN1
# Out:
# ['i10 MAGNA 1.2 KAPPA2 MANUAL',
#  'Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL',
#  'Wagon R 1.0 VXI MANUAL',
#  'Ameo TRENDLINE 1.2 MANUAL',
#  'Grand i10 MAGNA 1.2 VTVT MANUAL',
#  'Wagon R 1.0 VXI MANUAL',
#  'Wagon R 1.0 LXI MANUAL',
#  'Creta SX EXECUTIVE MT MANUAL',
#  'Amaze 1.2 SMT I VTEC MANUAL',
#  'Wagon R 1.0 LXI MANUAL',
#  'XUV500 W5 MANUAL',
#  'i10 MAGNA 1.2 KAPPA2 MANUAL',
#  'NEW I20 Asta 1.0 GDI Turbo IMT',
#  'Grand i10 MAGNA 1.2 KAPPA VTVT MANUAL',
#  'i10 SPORTZ 1.2 KAPPA2 MANUAL',
#  'Grand i10 SPORTZ AT 1.2 KAPPA VTVT AUTOMATIC',
#  'NEW I20 MAGNA 1.2 MT',
#  'Kiger RXZ 1.0 MT',
#  'Tiago XT 1.2 REVOTRON MANUAL',
#  'AURA E MT 1.2 KAPPA MANUAL',
#  'Swift LXI MANUAL',
#  'Wagon R 1.0 LXI MANUAL',
#  'Wagon R 1.0 VXI MANUAL',
#  'AURA S 1.2 Kappa MT MANUAL',
#  'Baleno SIGMA 1.2 K12 MANUAL',
#  'Compass 1.4 LONGITUDE (O) AT AUTOMATIC',
#  'AURA S 1.2 Kappa MT MANUAL',
#  'NEW SANTRO SPORTZ EXECUTIVE CNG MANUAL',
#  'Kwid Neotech 1.0 EasyR AUTOMATIC',
# ...

# %%
AutomaticN=[item.split(' ')[-1] for item in ModelN]
AutomaticN
# Out:
# ['MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'IMT',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MT',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'AUTOMATIC',
#  '7STR',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'RTN',
#  'AUTOMATIC',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  '1.2',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
# ...

# %%
Man_yearN=[item.split(' ')[0] for item in ModelN]
Man_yearN
# Out:
# ['2011',
#  '2014',
#  '2011',
#  '2018',
#  '2020',
#  '2010',
#  '2015',
#  '2021',
#  '2018',
#  '2014',
#  '2020',
#  '2011',
#  '2021',
#  '2019',
#  '2011',
#  '2017',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2019',
#  '2013',
#  '2011',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2022',
#  '2020',
#  '2020',
#  '2014',
#  '2022',
#  '2020',
#  '2022',
#  '2019',
#  '2009',
#  '2021',
#  '2018',
#  '2018',
#  '2020',
#  '2019',
#  '2019',
#  '2021',
#  '2021',
#  '2019',
#  '2014',
#  '2021',
#  '2020',
#  '2017',
#  '2011',
#  '2011',
#  '2014',
#  '2018',
#  '2021',
#  '2018',
#  '2021',
#  '2012',
#  '2020',
#  '2017',
#  '2014',
#  '2020',
#  '2022',
#  '2020',
#  '2021',
#  '2015',
#  '2015',
#  '2022',
#  '2018',
#  '2014',
#  '2018',
#  '2014',
#  '2021',
#  '2015',
#  '2014',
#  '2019',
#  '2019',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2014',
#  '2020',
#  '2011',
#  '2022',
#  '2020',
#  '2017',
#  '2018',
#  '2020',
#  '2017',
#  '2020',
# ...

# %%
KmN=[item.split(' ')[0] for item in DetailsN]
len(KmN)
# Out:
# 952

# %%
LocationN = ['Noida'] * 952

# %%
a=[item.split(' km')[1] for item in DetailsN]
FuelN=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
OwnerN=[item.split(' ')[0] for item in b]

# %%
PriceN1=[item.split('\n₹')[1] for item in PriceN]
len(PriceN1)
# Out:
# 952

# %%
len(VariantN)
# Out:
# 952

# %%
df3=pd.DataFrame({'Brand':BrandN,'Model':ModelN1,'Automatic':AutomaticN,'Variant':VariantN,'Km':KmN,'Location':LocationN,'Man_year':Man_yearN,'Fuel':FuelN,'Owner':OwnerN,'Price':PriceN1})
df3
# Out:
#           Brand                                   Model Automatic  \
# 0       Hyundai             i10 MAGNA 1.2 KAPPA2 MANUAL    MANUAL
# 1       Hyundai  Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL    MANUAL
# 2        Maruti                  Wagon R 1.0 VXI MANUAL    MANUAL
# 3    Volkswagen               Ameo TRENDLINE 1.2 MANUAL    MANUAL
# 4       Hyundai         Grand i10 MAGNA 1.2 VTVT MANUAL    MANUAL
# ..          ...                                     ...       ...
# 947      Maruti                 Baleno DELTA PETROL 1.2       1.2
# 948      Maruti                        Dzire VXI MANUAL    MANUAL
# 949     Hyundai        Verna FLUIDIC 1.6 SX VTVT MANUAL    MANUAL
# 950      Maruti                        Swift VXI MANUAL    MANUAL
# 951     Hyundai         Grand i10 MAGNA 1.2 VTVT MANUAL    MANUAL
#
#                           Variant      Km Location Man_year   Fuel Owner  \
# 0         MAGNA 1.2 KAPPA2 MANUAL  45,437    Noida     2011  Petro   1st
# ...

# %%
df3.to_csv('Car_Pricing4.csv')

# %%
driver.close()

# %% [markdown]
# # Location = Gurgaon

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=5&pinId=122001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_urlG=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_urlG.append(i.get_attribute("href"))
    
len(Product_urlG)
# Out:
# 964

# %%
del Product_urlG[-10:]
len(Product_urlG)
# Out:
# 954

# %%
BrandG=[]
ModelG=[]
VariantG=[]
DetailsG=[]
PriceG=[]

# %%
for url in Product_urlG:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandG.append(brand.text)
    except NoSuchElementException:
        BrandG.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelG.append(model.text)
    except NoSuchElementException:
        ModelG.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantG.append(variant.text)
    except NoSuchElementException:
        VariantG.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsG.append(details.text)
    except NoSuchElementException:
        DetailsG.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceG.append(price.text)
    except NoSuchElementException:
        PriceG.append('-')

# %%
ModelG1=[item.split(' ',2)[2] for item in ModelG]
ModelG1
# Out:
# ['Baleno SIGMA 1.2 K12 MANUAL',
#  'Compass 1.4 LONGITUDE (O) AT AUTOMATIC',
#  'Compass 2.0 LONGITUDE (O) MANUAL',
#  'AURA S 1.2 Kappa MT MANUAL',
#  'Baleno SIGMA 1.2 K12 MANUAL',
#  'City ZX CVT AUTOMATIC',
#  'VENUE S Plus MT 1.2 Kappa MANUAL',
#  'TIGUAN HIGHLINE A/T AUTOMATIC',
#  'Alto K10 VXI MANUAL',
#  'i20 SPORTZ 1.2 VTVT MANUAL',
#  'HECTOR SHARP DCT PETROL AUTOMATIC',
#  'Compass LIMITED 2.0 4*4 MANUAL',
#  'Compass 2.0 LIMITED MANUAL',
#  'NEW SANTRO ERA 1.1 MANUAL',
#  'i10 ERA 1.1 IRDE MANUAL',
#  'Swift LXI MANUAL',
#  'Kiger RXE 1.0 MT',
#  'HECTOR SHARP DCT PETROL AUTOMATIC',
#  'YARIS G CVT AUTOMATIC',
#  'Grand i10 MAGNA 1.2 KAPPA VTVT MANUAL',
#  'Swift LXI MANUAL',
#  'AURA E MT 1.2 KAPPA MANUAL',
#  'NEW SANTRO SPORTZ EXECUTIVE CNG MANUAL',
#  'Swift LXI MANUAL',
#  'Swift LXI MANUAL',
#  'AURA S 1.2 Kappa MT MANUAL',
#  'Kwid Neotech 1.0 EasyR AUTOMATIC',
#  'i10 MAGNA 1.1 IRDE2 MANUAL',
#  'Wagon R 1.0 LXI MANUAL',
#  'Swift LXI MANUAL',
# ...

# %%
AutomaticG=[item.split(' ')[-1] for item in ModelG]
AutomaticG
# Out:
# ['MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MT',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'RTN',
#  '7STR',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  '1.2',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'AUTOMATIC',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'AUTOMATIC',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MANUAL',
#  'MT',
#  'MANUAL',
#  'IMT',
#  '1.2',
# ...

# %%
KmG=[item.split(' ')[0] for item in DetailsG]
len(KmG)
# Out:
# 954

# %%
Man_yearG=[item.split(' ')[0] for item in ModelG]
len(Man_yearG)
# Out:
# 954

# %%
LocationG = ['Gurgaon'] * 954

# %%
a=[item.split(' km')[1] for item in DetailsG]
FuelG=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
OwnerG=[item.split(' ')[0] for item in b]

# %%
PriceG1=[item.split('\n₹')[1] for item in PriceG]
len(PriceG1)
# Out:
# 954

# %%
len(VariantG)
# Out:
# 954

# %%
df4=pd.DataFrame({'Brand':BrandG,'Model':ModelG1,'Automatic':AutomaticG,'Variant':VariantG,'Km':KmG,'Location':LocationG,'Man_year':Man_yearG,'Fuel':FuelG,'Owner':OwnerG,'Price':PriceG1})
df4
# Out:
#        Brand                                   Model  Automatic  \
# 0     Maruti             Baleno SIGMA 1.2 K12 MANUAL     MANUAL
# 1       Jeep  Compass 1.4 LONGITUDE (O) AT AUTOMATIC  AUTOMATIC
# 2       Jeep        Compass 2.0 LONGITUDE (O) MANUAL     MANUAL
# 3    Hyundai              AURA S 1.2 Kappa MT MANUAL     MANUAL
# 4     Maruti             Baleno SIGMA 1.2 K12 MANUAL     MANUAL
# ..       ...                                     ...        ...
# 949   Maruti                 Baleno DELTA PETROL 1.2        1.2
# 950   Maruti                        Dzire VXI MANUAL     MANUAL
# 951  Hyundai        Verna FLUIDIC 1.6 SX VTVT MANUAL     MANUAL
# 952   Maruti                        Swift VXI MANUAL     MANUAL
# 953  Hyundai         Grand i10 MAGNA 1.2 VTVT MANUAL     MANUAL
#
#                             Variant      Km Location Man_year   Fuel Owner  \
# 0              SIGMA 1.2 K12 MANUAL  16,054  Gurgaon     2020  Petro   1st
# ...

# %%
df4.to_csv('Car_Pricing5.csv')

# %%
driver.close()

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Location = Ahmedabad

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=1692&pinId=380001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_urlA=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_urlA.append(i.get_attribute("href"))
    
len(Product_urlA)
# Out:
# 288

# %%
del Product_urlA[-10:]
len(Product_urlA)
# Out:
# 278

# %%
BrandA=[]
ModelA=[]
VariantA=[]
DetailsA=[]
PriceA=[]

# %%
for url in Product_urlA:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandA.append(brand.text)
    except NoSuchElementException:
        BrandA.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelA.append(model.text)
    except NoSuchElementException:
        ModelA.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantA.append(variant.text)
    except NoSuchElementException:
        VariantA.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsA.append(details.text)
    except NoSuchElementException:
        DetailsA.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceA.append(price.text)
    except NoSuchElementException:
        PriceA.append('-')

# %%
ModelA1=[item.split(' ',2)[2] for item in ModelA]
len(ModelA1)
# Out:
# 278

# %%
AutomaticA=[item.split(' ')[-1] for item in ModelA]
len(AutomaticA)
# Out:
# 278

# %%
KmA=[item.split(' ')[0] for item in DetailsA]
len(KmA)
# Out:
# 278

# %%
Man_yearA=[item.split(' ')[0] for item in ModelA]
len(Man_yearA)
# Out:
# 278

# %%
LocationA = ['Ahmedabad'] * 278

# %%
len(VariantA)
# Out:
# 278

# %%
a=[item.split(' km')[1] for item in DetailsA]
FuelA=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
OwnerA=[item.split(' ')[0] for item in b]

# %%
PriceA1=[item.split('\n₹')[1] for item in PriceA]
len(PriceA1)
# Out:
# 278

# %%
df5=pd.DataFrame({'Brand':BrandA,'Model':ModelA1,'Automatic':AutomaticA,'Variant':VariantA,'Km':KmA,'Location':LocationA,'Man_year':Man_yearA,'Fuel':FuelA,'Owner':OwnerA,'Price':PriceA1})
df5
# Out:
#        Brand                        Model Automatic            Variant  \
# 0    Hyundai           Creta EX MT MANUAL    MANUAL       EX MT MANUAL
# 1     Maruti             Swift VXI MANUAL    MANUAL         VXI MANUAL
# 2     Maruti         Swift ZXI+ DUAL TONE      TONE     ZXI+ DUAL TONE
# 3     Maruti           Celerio VXI MANUAL    MANUAL         VXI MANUAL
# 4     Maruti             Swift VXI MANUAL    MANUAL         VXI MANUAL
# ..       ...                          ...       ...                ...
# 273  Hyundai  Elite i20 SPORTZ 1.2 MANUAL    MANUAL  SPORTZ 1.2 MANUAL
# 274   Maruti      Baleno ALPHA PETROL 1.2       1.2   ALPHA PETROL 1.2
# 275   Maruti       Wagon R 1.0 VXI MANUAL    MANUAL         VXI MANUAL
# 276  Renault          Kwid 1.0 RXT MANUAL    MANUAL     1.0 RXT MANUAL
# 277   Datsun         Redi Go T (O) MANUAL    MANUAL       T (O) MANUAL
#
#          Km   Location Man_year   Fuel Owner      Price
# 0     3,002  Ahmedabad     2021  Petro   2nd  12,27,599
# ...

# %%
df5.to_csv('Car_Pricing6.csv')

# %%
driver.close()

# %% [markdown]
# # Location = Chennai

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=5732&pinId=600001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_urlC=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_urlC.append(i.get_attribute("href"))
    
len(Product_urlC)
# Out:
# 446

# %%
del Product_urlC[-10:]
len(Product_urlC)
# Out:
# 436

# %%
BrandC=[]
ModelC=[]
VariantC=[]
DetailsC=[]
PriceC=[]

# %%
for url in Product_urlC:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandC.append(brand.text)
    except NoSuchElementException:
        BrandC.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelC.append(model.text)
    except NoSuchElementException:
        ModelC.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantC.append(variant.text)
    except NoSuchElementException:
        VariantC.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsC.append(details.text)
    except NoSuchElementException:
        DetailsC.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceC.append(price.text)
    except NoSuchElementException:
        PriceC.append('-')

# %%
len(BrandC)
# Out:
# 436

# %%
ModelC1=[item.split(' ',2)[2] for item in ModelC]
len(ModelC1)
# Out:
# 436

# %%
AutomaticC=[item.split(' ')[-1] for item in ModelC]
len(AutomaticC)
# Out:
# 436

# %%
KmC=[item.split(' ')[0] for item in DetailsC]
len(KmC)
# Out:
# 436

# %%
LocationC = ['Chennai'] * 436

# %%
Man_yearC=[item.split(' ')[0] for item in ModelC]
len(Man_yearC)
# Out:
# 436

# %%
len(VariantC)
# Out:
# 436

# %%
a=[item.split(' km')[1] for item in DetailsC]
FuelC=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
OwnerC=[item.split(' ')[0] for item in b]

# %%
PriceC1=[item.split('\n₹')[1] for item in PriceC]
len(PriceC1)
# Out:
# 436

# %%
df6=pd.DataFrame({'Brand':BrandC,'Model':ModelC1,'Automatic':AutomaticC,'Variant':VariantC,'Km':KmC,'Location':LocationC,'Man_year':Man_yearC,'Fuel':FuelC,'Owner':OwnerC,'Price':PriceC1})
df6
# Out:
#        Brand                         Model Automatic                 Variant  \
# 0       Tata          ALTROZ XE 1.2 MANUAL    MANUAL           XE 1.2 MANUAL
# 1     Maruti         Zen Estilo LXI MANUAL    MANUAL              LXI MANUAL
# 2     Maruti              Swift VXI MANUAL    MANUAL              VXI MANUAL
# 3     Nissan          MAGNITE XL Turbo CVT       CVT            XL Turbo CVT
# 4    Renault        Kiger RXL EASY R 1.0 L         L        RXL EASY R 1.0 L
# ..       ...                           ...       ...                     ...
# 431  Hyundai     Creta SX PETROL MT MANUAL    MANUAL     SX PETROL MT MANUAL
# 432  Hyundai     NEW SANTRO ERA 1.1 MANUAL    MANUAL          ERA 1.1 MANUAL
# 433    Honda  Amaze 1.2 VXMT I VTEC MANUAL    MANUAL  1.2 VXMT I VTEC MANUAL
# 434   Maruti          Swift VDI ABS MANUAL    MANUAL          VDI ABS MANUAL
# 435   Maruti           Alto 800 LXI MANUAL    MANUAL              LXI MANUAL
#
# ...

# %%
df6.to_csv('Car_Pricing7.csv')

# %%
driver.close()

# %% [markdown]
# # Location = Mumbai

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\DRiver\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(15)

# %%
Product_urlM=[]
url=driver.find_elements(By.XPATH,'//a[@target="_blank"]')
for i in url:
    Product_urlM.append(i.get_attribute("href"))
    
len(Product_urlM)
# Out:
# 493

# %%
del Product_urlM[-10:]
len(Product_urlM)
# Out:
# 483

# %%
BrandM=[]
ModelM=[]
VariantM=[]
DetailsM=[]
PriceM=[]

# %%
for url in Product_urlM:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//li[@class="breadcrumb-item"]')
        BrandM.append(brand.text)
    except NoSuchElementException:
        BrandM.append('-')
        
        
    try:
        model=driver.find_element(By.XPATH,'//h2[@class="_2geSF"]')
        ModelM.append(model.text)
    except NoSuchElementException:
        ModelM.append('-')
    
    
    try:
        variant=driver.find_element(By.XPATH,'//span[@class="_18vo2"]')
        VariantM.append(variant.text)
    except NoSuchElementException:
        VariantM.append('-')
        
    
    try:
        details=driver.find_element(By.XPATH,'//ul[@class="_2tp8h"]')
        DetailsM.append(details.text)
    except NoSuchElementException:
        DetailsM.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//strong[@class="_2yYvS Wqfj6"]')
        PriceM.append(price.text)
    except NoSuchElementException:
        PriceM.append('-')

# %%
len(BrandM)
# Out:
# 483

# %%
ModelM1=[item.split(' ',2)[2] for item in ModelM]
len(ModelM1)
# Out:
# 483

# %%
AutomaticM=[item.split(' ')[-1] for item in ModelM]
len(AutomaticM)
# Out:
# 483

# %%
KmM=[item.split(' ')[0] for item in DetailsM]
len(KmM)
# Out:
# 483

# %%
LocationM = ['Mumbai'] * 483

# %%
Man_yearM=[item.split(' ')[0] for item in ModelM]
len(Man_yearM)
# Out:
# 483

# %%
a=[item.split(' km')[1] for item in DetailsM]
FuelM=[item.split('l')[0] for item in a]
b=[item.split('l')[1] for item in a]
OwnerM=[item.split(' ')[0] for item in b]

# %%
PriceM1=[item.split('\n₹')[1] for item in PriceM]
len(PriceM1)
# Out:
# 483

# %%
len(VariantM)
# Out:
# 483

# %%
df7=pd.DataFrame({'Brand':BrandM,'Model':ModelM1,'Automatic':AutomaticM,'Variant':VariantM,'Km':KmM,'Location':LocationM,'Man_year':Man_yearM,'Fuel':FuelM,'Owner':OwnerM,'Price':PriceM1})
df7
# Out:
#        Brand                             Model Automatic  \
# 0     Maruti                  Swift VXI MANUAL    MANUAL
# 1    Hyundai        i10 MAGNA 1.1 IRDE2 MANUAL    MANUAL
# 2     Maruti                  Swift VXI MANUAL    MANUAL
# 3    Hyundai       i10 MAGNA 1.2 KAPPA2 MANUAL    MANUAL
# 4     Maruti       Baleno DELTA 1.2 K12 MANUAL    MANUAL
# ..       ...                               ...       ...
# 478  Hyundai               Xcent SX 1.2 MANUAL    MANUAL
# 479     Ford  Ecosport 1.5 TREND TI VCT MANUAL    MANUAL
# 480     Ford  Ecosport 1.5 TREND TI VCT MANUAL    MANUAL
# 481   Maruti        Wagon R 1.0 LXI CNG MANUAL    MANUAL
# 482     Ford  Ecosport 1.5TITANIUM TDCI MANUAL    MANUAL
#
#                      Variant      Km Location Man_year   Fuel Owner     Price
# 0                 VXI MANUAL  25,228   Mumbai     2020  Petro   1st  6,61,199
# 1     MAGNA 1.1 IRDE2 MANUAL  42,271   Mumbai     2015  Petro   2nd  3,01,699
# ...

# %%
df7.to_csv('Car_Pricing8.csv')

# %%
driver.close()

# %%
Bengaluru=pd.read_csv('Car_Pricing1.csv')
Hyderabad=pd.read_csv('Car_Pricing2.csv')
NewDelhi=pd.read_csv('Car_Pricing3.csv')
Noida=pd.read_csv('Car_Pricing4.csv')
Gurgaon=pd.read_csv('Car_Pricing5.csv')
Ahmedabad=pd.read_csv('Car_Pricing6.csv')
Chennai=pd.read_csv('Car_Pricing7.csv')
Mumbai=pd.read_csv('Car_Pricing8.csv')

# %%
df1=pd.DataFrame(Bengaluru)
df2=pd.DataFrame(Hyderabad)
df3=pd.DataFrame(NewDelhi)
df4=pd.DataFrame(Noida)
df5=pd.DataFrame(Gurgaon)
df6=pd.DataFrame(Ahmedabad)
df7=pd.DataFrame(Chennai)
df8=pd.DataFrame(Mumbai)

# %%
final_df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],ignore_index=True)
final_df
# Out:
#       Unnamed: 0    Brand                             Model Automatic  \
# 0              0   Maruti               Alto 800 LXI MANUAL    MANUAL
# 1              1   Maruti                   Ritz VXI MANUAL    MANUAL
# 2              2  Hyundai                    AURA SX (O) MT        MT
# 3              3  Hyundai            i20 MAGNA O 1.2 MANUAL    MANUAL
# 4              4   Maruti                  Swift ZXI MANUAL    MANUAL
# ...          ...      ...                               ...       ...
# 5229         478  Hyundai               Xcent SX 1.2 MANUAL    MANUAL
# 5230         479     Ford  Ecosport 1.5 TREND TI VCT MANUAL    MANUAL
# 5231         480     Ford  Ecosport 1.5 TREND TI VCT MANUAL    MANUAL
# 5232         481   Maruti        Wagon R 1.0 LXI CNG MANUAL    MANUAL
# 5233         482     Ford  Ecosport 1.5TITANIUM TDCI MANUAL    MANUAL
#
#                       Variant      Km   Location  Man_year   Fuel Owner  \
# ...

# %%
final_df.to_csv('Car_Pricing_final_data.csv')
