# %% [markdown]
# Q1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
Content=[]
content=driver.find_elements(By.TAG_NAME,'td')
for i in content[2:181]:
    content=i.text
    Content.append(content)

# %%
len(Content)
# Out:
# 179

# %%
Rank=Content[0::6]
Name=Content[1::6]
Artist=Content[2::6]
Upload_date=Content[4::6]
Views=Content[3::6]

# %%
print(len(Rank),len(Name),len(Artist),len(Upload_date),len(Views))
# Out:
# 30 30 30 30 30

# %%
df=pd.DataFrame({'Rank':Rank,'Most Viewed Video Name':Name,'Artist':Artist,'Publication date':Upload_date,'Views in billion':Views})
df
# Out:
#    Rank                           Most Viewed Video Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %%
driver.close()

# %% [markdown]
# Q2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/")

# %%
International_tag=driver.find_element(By.XPATH,".//*[contains(text(),'INTERNATIONAL')]")
International_tag.click()

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[4]/div/div[1]').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[4]/div/div[2]/div[1]/input').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[4]/div/div[2]/div[1]/input').send_keys('India')

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[4]/div/div[2]/div[3]').click()

# %%
driver.find_element(By.XPATH,'//div[@class="col-lg-12 col-md-12 col-sm-12"]').click()

# %%
Series=[]
series=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
for i in series:
    series=i.text
    Series.append(series)

# %%
Date=[]
date=driver.find_elements(By.XPATH,'//div[@class="match-card-left match-schedule"]')
for i in date:
    date=i.text
    Date.append(date)

# %%
Time=[]
time=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in time:
    time=i.text
    Time.append(time)

# %%
Match_title=[]
title=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
for i in title:
    title=i.text
    Match_title.append(title)

# %%
Location=[]
location=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]')
for i in location:
    location=i.text
    Location.append(location)

# %%
Location
# Out:
# ['1st T20I - Punjab Cricket Association IS Bindra Stadium, Mohali',
#  '2nd T20I - Vidarbha Cricket Association Stadium, Nagpur',
#  '3rd T20I - Rajiv Gandhi International Stadium, Hyderabad',
#  '1st T20I - Greenfield International Stadium, Thiruvananthapuram',
#  '2nd T20I - Barsapara Cricket Stadium, Guwahati',
#  '3rd T20I - Holkar Cricket Stadium, Indore',
#  '1st ODI - Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow',
#  '2nd ODI - JSCA International Stadium Complex, Ranchi',
#  '3rd ODI - Arun Jaitley Stadium, Delhi']

# %%
Place=[item.split(',',1)[1]for item in Location]
Place
# Out:
# [' Mohali',
#  ' Nagpur',
#  ' Hyderabad',
#  ' Thiruvananthapuram',
#  ' Guwahati',
#  ' Indore',
#  ' Lucknow',
#  ' Ranchi',
#  ' Delhi']

# %%
df=pd.DataFrame({'Match_title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})

# %%
df
# Out:
#   Match_title                                         Series  \
# 0  1st T20I -        AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 1  2nd T20I -        AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 2  3rd T20I -        AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 3  1st T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23
# 4  2nd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23
# 5  3rd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23
# 6   1st ODI -  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23
# 7   2nd ODI -  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23
# 8   3rd ODI -  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23
#
#                  Place         Date         Time
# 0               Mohali  20 SEP 2022  7:30 PM IST
# 1               Nagpur  23 SEP 2022  7:30 PM IST
# 2            Hyderabad  25 SEP 2022  7:30 PM IST
# 3   Thiruvananthapuram  28 SEP 2022  7:30 PM IST
# 4             Guwahati   2 OCT 2022  7:30 PM IST
# 5               Indore   4 OCT 2022  7:30 PM IST
# ...

# %%
driver.quit()

# %% [markdown]
# Q3. Scrape the details of selenium exception from guru99.com.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get("https://www.guru99.com/")

# %%
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
driver.find_element(By.XPATH,'/html/body/footer/div/div[1]/div/div/div/div/div/div/section/div/div/div[2]/div/div/div/div/div[2]/div/div/div[2]/div/div[2]/div/div/div[3]/div/div/div[2]/div/div/a/div[2]/h5').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').click()

# %%
Description=[]
description=driver.find_elements(By.TAG_NAME,'p')
for i in description[2:43]:
    description=i.text
    Description.append(description)

# %%
Description
# Out:
# ['1. ElementNotVisibleException: This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  '2. ElementNotSelectableException: This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  '3. NoSuchElementException: This Exception occurs if an element could not be found.',
#  '4. NoSuchFrameException: This Exception occurs if the frame target to be switched to does not exist.',
#  '5. NoAlertPresentException: This Exception occurs when you switch to no presented alert.',
#  '6. NoSuchWindowException: This Exception occurs if the window target to be switch does not exist.',
#  '7. StaleElementReferenceException: This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  '8. SessionNotFoundException: The WebDriver is acting after you quit the browser.',
# ...

# %%
Exception=[item.split(': ',1)[0]for item in Description]
Exception_Description=[item.split(': ',1)[1]for item in Description]

# %%
df=pd.DataFrame({'Exceptions':Exception,'Exception Description':Exception_Description})
df
# Out:
#                                  Exceptions  \
# 0             1. ElementNotVisibleException
# 1          2. ElementNotSelectableException
# 2                 3. NoSuchElementException
# 3                   4. NoSuchFrameException
# 4                5. NoAlertPresentException
# 5                  6. NoSuchWindowException
# 6         7. StaleElementReferenceException
# 7               8. SessionNotFoundException
# 8                       9. TimeoutException
# 9                    10. WebDriverException
# 10            11. ConnectionClosedException
# 11     12. ElementClickInterceptedException
# 12      13. ElementNotInteractableException
# 13             14. ErrorInResponseException
# 14  15. ErrorHandler.UnknownServerException
# 15         16. ImeActivationFailedException
# 16             17. ImeNotAvailableException
# 17         18. InsecureCertificateException
# 18             19. InvalidArgumentException
# 19         20. InvalidCookieDomainException
# ...

# %%
driver.close()

# %% [markdown]
# Q5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://github.com/')

# %%
driver.find_element(By.XPATH,'/html/body/div[1]/header/div[3]/nav/a[5]').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[5]/main/div[1]/nav/div/a[3]').click()

# %%
Repository_title=[]
title=driver.find_elements(By.XPATH,'//span[@class="text-normal"]')
for i in title:
    title=i.text
    Repository_title.append(title)

# %%
Repository_description=[]
description=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in description:
    description=i.text
    Repository_description.append(description)

# %%
Repository_description.append('-')

# %%
Details=[]
details=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
for i in details:
    details=i.text
    Details.append(details)

# %%
Contributors=Details[::2]

# %%
Des=[]
try:
    des=driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]')
    for i in des:
        des=i.text
        Des.append(des)
except NoSuchElementException:
    Des.append('-')

# %%
Language=[item.split(' ',1)[0]for item in Des]

# %%
for i in range(len(Language)):
    if Language[i] == '8,255':
        Language[i] = '-'
    if Language[i] == '42,195':
        Language[i] = '-'
    if Language[i] == '248,344':
        Language[i] = '-'
    if Language[i] == '164,950':
        Language[i] = '-'
    if Language[i] == '232,300':
        Language[i] = '-'
    if Language[i] == '232,300':
        Language[i] = '-'
    if Language[i] == '7,550':
        Language[i] = '-'
print(Language)
# Out:
# ['Python', 'TypeScript', 'Rust', '-', 'Jupyter', '-', '-', '-', 'C++', '-', 'TypeScript', 'Swift', 'TypeScript', 'Vue', '362', 'Python', 'Shell', 'Python', 'TypeScript', 'JavaScript', '-', 'C#', 'TypeScript', 'Python', 'C#']

# %%
df=pd.DataFrame({'Repository_title':Repository_title,'Repository_description':Repository_description,'Contributors':Contributors,'Language_used':Language})
df
# Out:
#      Repository_title                             Repository_description  \
# 0     TheAlgorithms /               All Algorithms implemented in Python
# 1            n8n-io /  Free and source-available fair-code licensed w...
# 2         surrealdb /  A scalable, distributed, collaborative, docume...
# 3         qazbnm456 /  🐶 A curated list of Web Security materials and...
# 4          karpathy /                      Neural Networks: Zero to Hero
# 5       Developer-Y /  List of Computer Science courses with video le...
# 6   EbookFoundation /               📚 Freely available programming books
# 7   codecrafters-io /  Master programming by recreating your favorite...
# 8        SerenityOS /                    The Serenity Operating System 🐞
# 9           jwasham /  A complete computer science study plan to beco...
# 10    kamranahmedse /            Roadmap to becoming a developer in 2022
# 11      danielgindi /  Beautiful charts for iOS/tvOS/OSX! The Apple s...
# ...

# %%
driver.close()

# %% [markdown]
# Q6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://www.billboard.com/')

# %%
driver.find_element(By.XPATH,'/html/body/div[3]/header/div[2]/div/nav/ul/li[2]/a').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a').click()

# %%
Details=[]
details=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]')
for i in details:
    details=i.text
    Details.append(details)

# %%
len(Details)
# Out:
# 100

# %%
Song_name=[item.split('\n',5)[0]for item in Details]
Artist_name=[item.split('\n',5)[1]for item in Details]
Last_week_rank=[item.split('\n',5)[2]for item in Details]
Peak_rank=[item.split('\n',5)[3]for item in Details]
weeks_onboard=[item.split('\n',5)[4]for item in Details]

# %%
df=pd.DataFrame({'Song name':Song_name,'Artist name':Artist_name,'Last week rank':Last_week_rank,'Peak rank':Peak_rank,'Weeks onboard':weeks_onboard})
df
# Out:
#                   Song name                       Artist name Last week rank  \
# 0                 As It Was                      Harry Styles              1
# 1                 Bad Habit                        Steve Lacy              2
# 2        Late Night Talking                      Harry Styles             12
# 3                   Sunroof                Nicky Youre & dazy              5
# 4           About Damn Time                             Lizzo              3
# ..                      ...                               ...            ...
# 95  Thought You Should Know                     Morgan Wallen             96
# 96               Country On                        Luke Bryan              -
# 97                   Static                        Steve Lacy              -
# 98           Billie Eilish.                      Armani White              -
# 99                  Sin Fin  Romeo Santos & Justin Timberlake              -
#
#    Peak rank Weeks onboard
# ...

# %%
driver.close()

# %% [markdown]
# Q7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
driver.find_element(By.XPATH,'//a[@title="Explore top companies hiring on Naukri"]').click()

# %%
driver.find_element(By.XPATH,'//span[@class="nI-gNb-sb__placeholder"]').click()

# %%
driver.find_element(By.XPATH,'/html/body/div/div[4]/div[2]/div[1]/div/div/div[1]/div/div/div/input').send_keys('Data Science')

# %%
driver.find_element(By.XPATH,'//span[@class="ni-gnb-icn ni-gnb-icn-search"]').click()

# %%
Designation=[]
start=0
end=3
for page in range(start,end):
    designation=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
    for i in designation:
        Designation.append(i.text)
    next_button=driver.find_element(By.XPATH,'//i[@class="naukicon naukicon-arrow ml-8 fleft fs16"]')
    next_button.click()
    time.sleep(3)

# %%
Page1=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[2]/div[3]/div/div/a[1]').click()

# %%
Company=[]
start=0
end=3
for page in range(start,end):
    company=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
    for i in company:
        Company.append(i.text)
    next_button=driver.find_element(By.XPATH,'//i[@class="naukicon naukicon-arrow ml-8 fleft fs16"]')
    next_button.click()
    time.sleep(3)

# %%
Page1=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[2]/div[3]/div/div/a[1]').click()

# %%
Location=[]
start=0
end=3
for page in range(start,end):
    location=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
    for i in location:
        Location.append(i.text)
    next_button=driver.find_element(By.XPATH,'//i[@class="naukicon naukicon-arrow ml-8 fleft fs16"]')
    next_button.click()
    time.sleep(3)

# %%
Page1=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[2]/div[3]/div/div/a[1]').click()

# %%
Skills=[]
start=0
end=3
for page in range(start,end):
    skills=driver.find_elements(By.XPATH,'//ul[@class="tags has-description"]')
    for i in skills:
        Skills.append(i.text)
    next_button=driver.find_element(By.XPATH,'//i[@class="naukicon naukicon-arrow ml-8 fleft fs16"]')
    next_button.click()
    time.sleep(5)

# %%
print(len(Skills),len(Designation),len(Company),len(Location))
# Out:
# 59 59 59 59

# %%
df=pd.DataFrame({'Company':Company,'Designation':Designation,'Location':Location,'Skills they hire for':Skills})
df
# Out:
#                                               Company  \
# 0                                           Accenture
# 1                                    Citicorp Finance
# 2                               Bartleby Technologies
# 3                                STARAGILE CONSULTING
# 4                         CliqHR Recruitment Services
# 5                           United Phosphorus Limited
# 6                           United Phosphorus Limited
# 7   Xpressbees (BusyBees Logistics Solutions Pvt. ...
# 8                                         Evalueserve
# 9                                         Evalueserve
# 10                                        Evalueserve
# 11                                        Evalueserve
# 12                               Golden Opportunities
# 13                                        DataTrained
# 14                          Huquo Consulting Pvt. Ltd
# 15                          Huquo Consulting Pvt. Ltd
# ...

# %%
driver.close()

# %% [markdown]
# Q8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-
# compare/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
Details=[]
details=driver.find_elements(By.XPATH,'//td[@class="left"]')
for i in details:
    details=i.text
    Details.append(details)

# %%
len(Details)
# Out:
# 500

# %%
Book_name=Details[1::5]
Author_name=Details[2::5]
Volumes_sold=Details[3::5]
Publisher=Details[4::5]

# %%
Genre=[]
genre=driver.find_elements(By.XPATH,'//td[@class="last left"]')
for i in genre:
    genre=i.text
    Genre.append(genre)

# %%
df=pd.DataFrame({'Book name':Book_name,'Author name':Author_name,'Volumes sold':Volumes_sold,'Publisher':Publisher,'Genre':Genre})
df
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# Q9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
Series=[]
series=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
for i in series:
    series=i.text
    Series.append(series)

# %%
Year_span=[item.split('(',1)[1]for item in Series]
Name=[item.split('(',1)[0]for item in Series]
Name1=[item.split('. ',1)[1]for item in Name]

# %%
Genre=[]
genre=driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in genre:
    genre=i.text
    Genre.append(genre)

# %%
Runtime=[]
runtime=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in runtime:
    runtime=i.text
    Runtime.append(runtime)

# %%
Ratings=[]
ratings=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in ratings:
    ratings=i.text
    Ratings.append(ratings)

# %%
Votes=[]
votes=driver.find_elements(By.XPATH,'//span[@name="nv"]')
for i in votes:
    votes=i.text
    Votes.append(votes)

# %%
print(len(Name1),len(Year_span),len(Genre),len(Runtime),len(Ratings),len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
df=pd.DataFrame({'Series name':Name1,'Year span':Year_span,'Genre':Genre,'Run time':Runtime,'Ratings':Ratings,'Votes':Votes})
df
# Out:
#                         Series name   Year span                     Genre  \
# 0                  Game of Thrones   2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things      2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead   2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why   2017–2020)  Drama, Mystery, Thriller
# 4                          The 100   2014–2020)    Drama, Mystery, Sci-Fi
# ..                              ...         ...                       ...
# 95                           Reign   2013–2017)                     Drama
# 96  A Series of Unfortunate Events   2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds   2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series   2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House        2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,048,881
# ...

# %%
driver.close()

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://archive.ics.uci.edu/ml/index.php')

# %%
driver.find_element(By.XPATH,'/html/body/table[2]/tbody/tr/td/span/b/a').click()

# %%
Details=[]
details=driver.find_elements(By.XPATH,'//p[@class="normal"]')
for i in details[9:]:
    details=i.text
    Details.append(details)

# %%
Details.insert(0, "Abalone")

# %%
Datasetname=Details[0::7]
Datatype=Details[1::7]
Task=Details[2::7]
Attributetype=Details[3::7]
No_of_instances=Details[4::7]
No_of_attributes=Details[5::7]
Year=Details[6::7]

# %%
Datasetname.pop()
# Out:
# 'Supported By:'

# %%
print(len(Datasetname),len(Datatype),len(Task),len(Attributetype),len(No_of_instances),len(No_of_attributes),len(Year))
# Out:
# 622 623 622 622 622 622 622

# %%
Datatype.pop()
# Out:
# ' In Collaboration With:'

# %%
df=pd.DataFrame({'Dataset name':Datasetname,'Datatype':Datatype,'Task':Task,'Attributetype':Attributetype,'No. of instances':No_of_instances,'No. of attributes':No_of_attributes,'Year':Year})
df
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                        Datatype                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %%
driver.close()

# %% [markdown]
# Q4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.ui import Select

# %%
driver=webdriver.Chrome(r"C:\Users\91994\Desktop\FlipRobo_Technologies\chromedriver.exe")

# %%
driver.get('https://www.statisticstimes.com/')

# %%
drop=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]').click()

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
Rank=[]
rank=driver.find_elements(By.XPATH,'//td[@class="data1"]')
for i in rank[0:33]:
    rank=i.text
    Rank.append(rank)
    
State=[]
state=driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in state[0:33]:
    state=i.text
    State.append(state)

# %%
print(len(Rank),len(State))
# Out:
# 33 33

# %%
GSDP=[]
gsdp=driver.find_elements(By.XPATH,'//td[@class="data"]')
for i in gsdp[0:165]:
    gsdp=i.text
    GSDP.append(gsdp)

# %%
GSDP1920=GSDP[0::5]
Share1819=GSDP[1::5]
GDPbillion=GSDP[2::5]

# %%
print(len(GSDP1920),len(Share1819),len(GDPbillion))
# Out:
# 33 33 33

# %%
GSDP1819=[]
gsdp1819=driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
for i in gsdp1819[0:33]:
    gsdp1819=i.text
    GSDP1819.append(gsdp1819)

# %%
df=pd.DataFrame({'Rank':Rank,'State':State,'GSDP 19-20':GSDP1920,'GSDP 18-19':GSDP1819,'Share 18-19':Share1819,'GDP $ billion':GDPbillion})
df
# Out:
#    Rank                      State GSDP 19-20 GSDP 18-19 Share 18-19  \
# 0     1                Maharashtra          -  2,632,792      13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208       8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764       8.39%
# 3     4                    Gujarat          -  1,502,899       7.96%
# 4     5                  Karnataka  1,631,977  1,493,127       7.91%
# 5     6                West Bengal  1,253,832  1,089,898       5.77%
# 6     7                  Rajasthan  1,020,989    942,586       4.99%
# 7     8             Andhra Pradesh    972,782    862,957       4.57%
# 8     9                  Telangana    969,604    861,031       4.56%
# 9    10             Madhya Pradesh    906,672    809,592       4.29%
# 10   11                     Kerala          -    781,653       4.14%
# 11   12                      Delhi    856,112    774,870       4.10%
# 12   13                    Haryana    831,610    734,163       3.89%
# ...

# %%
driver.close()
